# %%
import os
from PIL import Image
import json

# %%
data_path = r"/home/alex/data/nlp/agmir"
img_path = os.path.join(data_path, r"img")
captions_path = os.path.join(data_path, r"txt/ecgen-radiology")

# %%
imgs = os.listdir(img_path)
captions = os.listdir(captions_path)
print(len(imgs), len(captions))
# Out:
# 7471 3955

# %% [markdown]
# ### test loading one image

# %%
Image.open(os.path.join(img_path,imgs[0]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F545E226390>

# %% [markdown]
# ### parse captions

# %%
import xml.etree.ElementTree as ET

# %%
# %%time
cases = []
for case in captions[:]:
    xml_data = os.path.join(captions_path, case)
    etree = ET.parse(xml_data) #create an ElementTree object 
    eroot = etree.getroot()
    case_data = {}
    case_data['id'] = eroot.findall("uId")[0].get("id")
    text_nodes = eroot.findall("MedlineCitation")[0].findall("Article")[0].findall("Abstract")[0].findall("AbstractText")
    for node in text_nodes:
        case_data[node.get("Label").lower()] = node.text
    case_data['tags_manual'] = [t.text for t in eroot.findall("MeSH")[0].findall("major")]
    case_data['tags_mti'] = [t.text for t in eroot.findall("MeSH")[0].findall("automatic")]
    cases.append(case_data)
# Out:
# CPU times: user 772 ms, sys: 48 ms, total: 820 ms
# Wall time: 819 ms

# %% [markdown]
# ### map w/ images

# %%
# %%time
for case in cases:
    case['images'] = [img for img in imgs if case['id']+"_" in img]
# Out:
# CPU times: user 3.46 s, sys: 24 ms, total: 3.49 s
# Wall time: 3.49 s

# %%
count = 0
for case in cases:
    if len(case['images']) > 0:
        count += 1
print(count, len(cases))
# Out:
# 3851 3955

# %%
cases
# Out:
# [{'id': 'CXR2216',
#   'comparison': 'None',
#   'indication': 'XXXX with low-grade XXXX and midback pain x2 weeks.',
#   'findings': 'Heart size and mediastinal contours are within normal limits. Pulmonary vasculature is unremarkable. No focal airspace consolidation. There is mild elevation right hemidiaphragm. No visible pleural effusion or pneumothorax. There are mild degenerative changes along the thoracic spine.',
#   'impression': '1. Mildly elevated right hemidiaphragm. Otherwise no acute cardiopulmonary abnormality seen.',
#   'tags_manual': ['Diaphragm/right/elevated/mild',
#    'Thoracic Vertebrae/degenerative/mild'],
#   'tags_mti': ['degenerative change', 'Diaphragm'],
#   'images': ['CXR2216_IM-0821-85075001.png', 'CXR2216_IM-0821-85075002.png']},
#  {'id': 'CXR4',
#   'comparison': 'None available',
#   'indication': 'XXXX-year-old XXXX with XXXX.',
#   'findings': 'There are diffuse bilateral interstitial and alveolar opacities consistent with chronic obstructive lung disease and bullous emphysema. There are irregular opacities in the left lung apex, that could represent a cavitary lesion in the left lung apex.There are streaky opacities in the right upper lobe, XXXX scarring. The cardiomediastinal silhouette is normal in size and contour. There is no pneumothorax or large pleural effusion.',
#   'impression': '1. Bullous emphysema and interstitial fibrosis. 2. Probably scarring in the left apex, although difficult to exclude a cavitary lesion. 3. Opacities in the bilateral upper lobes could represent scarring, however the absence of comparison exam, recommend short interval followup radiograph or CT thorax to document resolution.',
#   'tags_manual': ['Pulmonary Disease, Chronic Obstructive',
#    'Bullous Emphysema',
#    'Pulmonary Fibrosis/interstitial',
#    'Cicatrix/lung/upper lobe/left',
#    'Opacity/lung/apex/left/irregular',
#    'Opacity/lung/upper lobe/right/streaky',
#    'Opacity/pulmonary alveoli',
#    'Opacity/lung/bilateral/interstitial/diffuse'],
#   'tags_mti': ['bullous emphysema',
#    'chronic obstructive lung disease',
#    'interstitial fibrosis',
#    'opacity',
#    'scarring',
#    'Chronic Obstructive Lung Disease',
#    'Emphysema',
#    'Lung Diseases, Interstitial',
#    'Pulmonary Emphysema',
#    'Scarring'],
#   'images': ['CXR4_IM-2050-1001.png', 'CXR4_IM-2050-2001.png']},
#  {'id': 'CXR1230',
#   'comparison': None,
#   'indication': 'followup consolidation mass. Brain metastasis versus abscess.',
#   'findings': None,
#   'impression': 'Left lung clear. Slight cardiomegaly. Right effusion. Right lower lobe infiltrate. Two air-fluid levels in the right hemithorax most XXXX representing hydropneumothorax. This radiographic finding could also represent empyema with a bronchopleural fistula. CT scan with IV contrast may be helpful.',
#   'tags_manual': ['Cardiomegaly/mild',
#    'Pleural Effusion/right',
#    'Infiltrate/lung/lower lobe/right',
#    'Hydropneumothorax/right'],
#   'tags_mti': ['bronchopleural fistula',
#    'effusion',
#    'empyema',
#    'infiltrates',
#    'Bronchial Fistula',
#    'Cardiomegaly',
#    'Empyema',
#    'Hydropneumothorax',
#    'Pleural Diseases'],
#   'images': ['CXR1230_IM-0154-1001.png',
#    'CXR1230_IM-0154-0001.png',
#    'CXR1230_IM-0154-2001.png']},
#  {'id': 'CXR1146',
#   'comparison': 'None',
#   'indication': "XXXX doesn't feel well, under a XXXX of XXXX",
#   'findings': 'Heart size is normal. The lungs are clear. There are no focal air space consolidations. No pleural effusions or pneumothoraces. The hilar and mediastinal contours are normal. Calcified lingular pulmonary granuloma. Normal pulmonary vascularity.',
#   'impression': 'No acute abnormality.',
#   'tags_manual': ['Calcified Granuloma/lung/lingula'],
#   'tags_mti': ['pulmonary granuloma'],
#   'images': ['CXR1146_IM-0098-2001.png', 'CXR1146_IM-0098-1001.png']},
#  {'id': 'CXR566',
#   'comparison': None,
#   'indication': None,
#   'findings': None,
#   'impression': None,
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': []},
#  {'id': 'CXR1817',
#   'comparison': None,
#   'indication': 'Generalized weakness.',
#   'findings': "The XXXX examination consists of frontal and lateral radiographs of the chest. Upper thorax is poorly visualized due to patient's overlying head and chin. The cardiomediastinal contours are within normal limits. Background of mild coarse interstitial opacities seen throughout the lungs XXXX related to background of emphysema. Calcified granuloma is seen in the left medial lung base. There is no consolidation, pleural effusion or pneumothorax. Deformity of the right 6th rib laterally has appearance of acute or subacute fracture. Degenerative changes of the thoracic spine are again seen.",
#   'impression': 'Age indeterminant but XXXX acute to subacute right 6th rib fracture.',
#   'tags_manual': ['Technical Quality of Image Unsatisfactory ',
#    'Opacity/lung/bilateral/interstitial/mild',
#    'Emphysema',
#    'Calcified Granuloma/lung/base/left',
#    'Deformity/ribs/right',
#    'Fractures, Bone/ribs/right',
#    'Thoracic Vertebrae/degenerative'],
#   'tags_mti': ['Rib',
#    'calcified granuloma',
#    'deformity',
#    'degenerative change',
#    'emphysemas',
#    'fracture',
#    'opacity',
#    'rib fracture',
#    'Fractures, Bone',
#    'Pulmonary Emphysema',
#    'Rib Fracture',
#    'Spine'],
#   'images': ['CXR1817_IM-0529-4004.png']},
#  {'id': 'CXR3743',
#   'comparison': 'XXXX, XXXX.',
#   'indication': 'chest pain/dyspnea',
#   'findings': 'The heart and lungs have XXXX XXXX in the interval. Both lungs are clear and expanded. Heart and mediastinum normal.',
#   'impression': 'No active disease.',
#   'tags_manual': ['No Indexing'],
#   'tags_mti': [],
#   'images': ['CXR3743_IM-1870-1001.png']},
#  {'id': 'CXR620',
#   'comparison': 'Chest x-XXXX dated XXXX, XXXX.',
#   'indication': '786.05 shortness of breath',
#   'findings': 'There is no focal consolidation, pleural effusion, or pneumothorax. Stable left lower lobe scarring. Normal heart size and pulmonary vascularity. There are degenerative changes of the thoracic spine noted.',
#   'impression': 'No acute cardiopulmonary abnormality. .',
#   'tags_manual': ['Cicatrix/lung/lower lobe/left',
#    'Thoracic Vertebrae/degenerative'],
#   'tags_mti': ['degenerative change', 'scarring'],
#   'images': ['CXR620_IM-2202-1001.png', 'CXR620_IM-2202-2001.png']},
#  {'id': 'CXR2686',
#   'comparison': 'None available.',
#   'indication': 'XXXX-year-old female with chest pain.',
#   'findings': 'Heart size within normal limits. No focal airspace disease. No pneumothorax or effusions.',
#   'impression': 'No acute cardiopulmonary findings.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2686_IM-1158-2001.png', 'CXR2686_IM-1158-1001.png']},
#  {'id': 'CXR156',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'Pain and difficulty breathing',
#   'findings': 'Stable left-sided ICD and postsurgical changes consistent with prior CABG. The cardiomediastinal silhouette and vasculature are within normal limits for size and contour. The lungs are normally inflated and clear. Mild degenerative endplate changes of the spine.',
#   'impression': '1. No acute radiographic cardiopulmonary process.',
#   'tags_manual': ['Implanted Medical Device/left', 'Spine/degenerative'],
#   'tags_mti': ['cabg'],
#   'images': []},
#  {'id': 'CXR2891',
#   'comparison': 'chest x-XXXX XXXX,',
#   'indication': 'Chest and hip XXXX from XXXX.',
#   'findings': 'Both lungs remain clear and expanded. No focal parenchymal infiltrates or pleural air collections. Heart and aorta are normal. No change in the large hiatus hernia. Pelvis. Bone density is decreased. Hips are normal and symmetric. No fractures, dislocations, or bone destruction. Note XXXX of a severe rotatory dextroscoliosis in the lumbar spine.',
#   'impression': '1. Chest. No change no active cardiopulmonary disease. No evidence for cardiopulmonary injury. 2. Pelvis and hips negative for recent bony injury.',
#   'tags_manual': ['Hernia, Hiatal/large'],
#   'tags_mti': ['hiatus hernia'],
#   'images': ['CXR2891_IM-1294-1001.png']},
#  {'id': 'CXR2853',
#   'comparison': 'Comparison is XXXX to chest radiograph examination dated XXXX.',
#   'indication': 'XXXX-year-old female with chest pain.',
#   'findings': 'A cardiac defibrillator device is in XXXX over the left chest wall with a single XXXX projecting over the right ventricle. The cardiac silhouette is at the upper limits of normal for size. The thoracic aorta is mildly tortuous and calcified. No focal areas of pulmonary consolidation. No pneumothorax. No pleural effusion. Minimal degenerative endplate changes of the thoracic spine. No acute, displaced rib fractures.',
#   'impression': '1. No acute intrathoracic abnormality.',
#   'tags_manual': ['Implanted Medical Device/left',
#    'Aorta, Thoracic/tortuous/mild',
#    'Calcinosis/aorta, thoracic',
#    'Thoracic Vertebrae/degenerative/mild'],
#   'tags_mti': ['Thoracic Aorta'],
#   'images': []},
#  {'id': 'CXR1034',
#   'comparison': 'XXXX, XXXX.',
#   'indication': '10 XXXX hx of XXXX, SOB, wheezing in XXXX XXXX',
#   'findings': 'The heart and lungs have XXXX XXXX in the interval. Both lungs are clear and expanded. Right middle lobe calcified granuloma is unchanged. Heart and mediastinum unchanged. No change hiatus hernia.',
#   'impression': 'No active disease.',
#   'tags_manual': ['Calcified Granuloma/lung/middle lobe/right',
#    'Hernia, Hiatal'],
#   'tags_mti': ['calcified granuloma', 'hiatus hernia', 'Hernia, Hiatus'],
#   'images': ['CXR1034_IM-0028-1001.png', 'CXR1034_IM-0028-1002.png']},
#  {'id': 'CXR2616',
#   'comparison': 'None.',
#   'indication': 'History of XXXX. Increasing right lower extremity pain.',
#   'findings': 'Frontal and lateral views of the chest show normal size and configuration of the cardiac silhouette. The right costophrenic sulcus is blunted. There is an the right base XXXX/fluid level. The left lung is clear.',
#   'impression': '1. Right-sided small pleural effusion. 2. Right base XXXX/fluid level. Atypical location for a hiatal hernia. Cannot exclude a right lower lobe cavity. Correlation XXXX scan recommended. Does not appear to be a hydropneumothorax or empyema.',
#   'tags_manual': ['Costophrenic Angle/sulcus/right/blunted',
#    'Pleural Effusion/right/small',
#    'Hernia, Hiatal'],
#   'tags_mti': ['hiatal hernia',
#    'pleural effusions',
#    'Hiatal Hernia',
#    'Pleural Effusion'],
#   'images': ['CXR2616_IM-1106-1001.png', 'CXR2616_IM-1106-2001.png']},
#  {'id': 'CXR1819',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'Dyspnea',
#   'findings': None,
#   'impression': 'Stable cardiac enlargement. Vascular congestion is redemonstrated. Patchy atelectasis and airspace disease is present in the left base. Right base is clear. No large effusion or pneumothorax.',
#   'tags_manual': ['Cardiomegaly',
#    'Pulmonary Congestion',
#    'Pulmonary Atelectasis/base/left/patchy',
#    'Airspace Disease/lung/base/left'],
#   'tags_mti': ['congestion',
#    'patchy atelectasis',
#    'Cardiomegaly',
#    'Pulmonary Atelectasis'],
#   'images': ['CXR1819_IM-0530-1001-0001.png',
#    'CXR1819_IM-0530-1001-0002.png']},
#  {'id': 'CXR1557',
#   'comparison': 'Comparison is XXXX to chest radiograph examination dated XXXX.',
#   'indication': 'XXXX-year-old male with a history of partial right lung resection presents for evaluation.',
#   'findings': 'There is interval removal of the tracheostomy tube and right subclavian central venous catheter. The cardiac silhouette is mildly enlarged. There are XXXX XXXX pulmonary opacities with blunting of the bilateral costophrenic XXXX, on the right greater than left, with pleural thickening versus loculated pleural fluid along the peripheral aspect of the right upper lobe. Right perihilar opacities. No pneumothorax identified.',
#   'impression': '1. Enlarged cardiac silhouette, possibly consistent with mild cardiomegaly versus a small pericardial effusion. 2. Mild bibasilar atelectasis and/or infiltrates with probable small bilateral pleural effusions, on the right greater than left, and pleural thickening versus loculated pleural fluid along the peripheral aspect of the right upper lobe. .',
#   'tags_manual': ['Cardiac Shadow/enlarged/mild',
#    'Opacity/lung',
#    'Costophrenic Angle/bilateral/blunted',
#    'Thickening/pleura/upper lobe/right',
#    'Pleural Effusion/upper lobe/right',
#    'Opacity/lung/hilum/right',
#    'Pulmonary Atelectasis/base/bilateral/mild',
#    'Infiltrate/lung/base/bilateral/mild',
#    'Pleural Effusion/bilateral/small'],
#   'tags_mti': ['atelectases',
#    'bilateral pleural effusion',
#    'infiltrates',
#    'opacity',
#    'pericardial effusion',
#    'pleural fluid',
#    'pleural thickening',
#    'Atelectasis',
#    'Cardiomegaly',
#    'Pericardial Effusion',
#    'Pleural Diseases',
#    'Pleural Effusion'],
#   'images': ['CXR1557_IM-0364-4004.png']},
#  {'id': 'CXR3808',
#   'comparison': 'Frontal chest radiograph dated XXXX',
#   'indication': 'XXXX',
#   'findings': 'Heart size and mediastinal contour within normal limits. Atherosclerotic calcification of the aorta. Stable scattered calcified granulomas are noted. No focal airspace consolidation, pneumothorax, or large pleural effusion. No acute osseous abnormality.',
#   'impression': 'No acute abnormality.',
#   'tags_manual': ['Atherosclerosis/aorta',
#    'Calcified Granuloma/scattered/multiple'],
#   'tags_mti': ['calcifications of the aorta',
#    'calcified granuloma',
#    'Calcinosis'],
#   'images': ['CXR3808_IM-1918-1002.png', 'CXR3808_IM-1918-1001.png']},
#  {'id': 'CXR1885',
#   'comparison': 'XXXX, XXXX.',
#   'indication': 'XXXX',
#   'findings': 'Heart size is normal. Mediastinal contour and pulmonary vascularity within normal limits. No focal airspace consolidation, pneumothorax, or pleural effusion. No acute bony abnormality.',
#   'impression': 'Clear lungs, no acute cardiopulmonary abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1885_IM-0574-2001.png', 'CXR1885_IM-0574-1001.png']},
#  {'id': 'CXR2692',
#   'comparison': '.',
#   'indication': 'CP/COPD no known XXXX. mid-XXXX chest pain with inspiration X 3 weeks ago. pt states "pain XXXX for a few days not XXXX and on". no prev. inj/XXXX. nonsmoker. no XXXX of pregnancy, shielded.',
#   'findings': None,
#   'impression': 'Normal heart size. Normal pulmonary vasculature. Normal mediastinal contours. Lung parenchyma is clear. No airspace disease. No pulmonary edema. No XXXX of pleural effusions. No XXXX of active cardiopulmonary disease. Unchanged.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2692_IM-1164-1001.png', 'CXR2692_IM-1164-2001.png']},
#  {'id': 'CXR238',
#   'comparison': 'XXXX.',
#   'indication': 'Shortness of breath.',
#   'findings': 'Stable cardiomediastinal silhouette. No focal pulmonary opacity, pleural effusion or pneumothorax. No acute bony abnormality.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR238_IM-0939-2001.png', 'CXR238_IM-0939-1001.png']},
#  {'id': 'CXR3982',
#   'comparison': '8 XXXX 08.',
#   'indication': 'XXXX-year-old male with epigastric pain.',
#   'findings': 'Normal heart size. No focal airspace consolidation, pneumothorax, pleural effusion, or pulmonary edema. No focal bony abnormality.',
#   'impression': 'No acute cardiothoracic abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR3982_IM-2039-2001.png', 'CXR3982_IM-2039-1001.png']},
#  {'id': 'CXR2026',
#   'comparison': 'None available.',
#   'indication': 'The patient is a XXXX-year-old XXXX with back pain.',
#   'findings': 'The trachea is midline. Cardiomediastinal silhouette is normal. The lungs are clear, without evidence of focal consolidation or pleural effusion. There is no pneumothorax. The visualized bony structures reveal no acute abnormalities.',
#   'impression': 'No acute cardiopulmonary abnormalities. .',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2026_IM-0671-2001.png', 'CXR2026_IM-0671-1001.png']},
#  {'id': 'CXR3407',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'Altered mental status',
#   'findings': 'Intact XXXX sternotomy XXXX and CABG markers. Calcified granulomas. Heart size is normal. No focal airspace consolidation, suspicious pulmonary opacity, pneumothorax, or pleural effusion. T-spine degenerative changes.',
#   'impression': 'Postsurgical changes of CABG without acute cardiopulmonary abnormality.',
#   'tags_manual': ['Calcified Granuloma/multiple',
#    'Thoracic Vertebrae/degenerative'],
#   'tags_mti': ['calcified granuloma',
#    'degenerative change',
#    'cabg',
#    'sternotomy',
#    'Sternotomy'],
#   'images': ['CXR3407_IM-1647-2001.png', 'CXR3407_IM-1647-1001.png']},
#  {'id': 'CXR2290',
#   'comparison': 'None',
#   'indication': 'XXXX year-old male, XXXX.',
#   'findings': 'There are no focal areas of consolidation. No suspicious pulmonary opacities. Heart size within normal limits. No pleural effusions. No evidence of pneumothorax. Osseous structures are intact.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2290_IM-0874-4001.png', 'CXR2290_IM-0874-1001.png']},
#  {'id': 'CXR124',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old female, short of breath, hypoxia',
#   'findings': None,
#   'impression': 'Large left pleural effusion with minimal residual left lung aeration. Small right pleural effusion. Right lung bronchovascular crowding and indistinct vascular margination which may be secondary to crowding, infiltrates or pulmonary edema. Limited assessment of heart size due to obscured heart XXXX.',
#   'tags_manual': ['Pleural Effusion/left/large',
#    'Lung/left/hypoinflation',
#    'Pleural Effusion/right/small',
#    'Markings/lung/right/bronchovascular',
#    'Pulmonary Congestion/right'],
#   'tags_mti': ['infiltrates',
#    'pleural effusions',
#    'pulmonary edema',
#    'Pleural Effusion',
#    'Pulmonary Edema'],
#   'images': ['CXR124_IM-0161-4004.png', 'CXR124_IM-0161-1001.png']},
#  {'id': 'CXR3205',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old female, evaluate for rib fractures post XXXX',
#   'findings': 'No pneumothorax. Heart size is normal. No large pleural effusions. No focal airspace opacities. No definite visualized rib fractures.',
#   'impression': 'No acute cardiopulmonary abnormalities. No visualized rib fractures.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR3205_IM-1513-1002.png', 'CXR3205_IM-1513-1001.png']},
#  {'id': 'CXR3391',
#   'comparison': 'PA and lateral views of the chest dated XXXX.',
#   'indication': 'XXXX-year-old female, nausea, vomiting.',
#   'findings': 'There are no focal areas of consolidation. No suspicious pulmonary opacities. Heart size within normal limits. No pleural effusions. There is no evidence of pneumothorax. Stable left mid lung granuloma.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['Granuloma/lung/lingula'],
#   'tags_mti': ['lung granuloma'],
#   'images': ['CXR3391_IM-1637-2001.png', 'CXR3391_IM-1637-1001.png']},
#  {'id': 'CXR1621',
#   'comparison': 'CT chest XXXX, XXXX, chest x-XXXX XXXX',
#   'indication': 'XXXX-year-old female with XXXX onset, XXXX with wheezing in bilateral lung XXXX.',
#   'findings': 'The trachea is midline. Negative for pneumothorax, pleural effusion or focal airspace consolidation. The heart size is at the upper limits of normal. Calcified granuloma in the right lower lobe is stable in appearance XXXX compared to the previous examinations.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['Calcified Granuloma/lung/lower lobe/right'],
#   'tags_mti': ['calcified granuloma'],
#   'images': ['CXR1621_IM-0403-1001.png', 'CXR1621_IM-0403-1002.png']},
#  {'id': 'CXR1110',
#   'comparison': 'XXXX.',
#   'indication': 'XXXX-year-old male, chest pain.',
#   'findings': 'Cardiomediastinal contours within normal limits. Pulmonary vascularity is normal. There are scattered calcified testes bilaterally, consistent with prior granulomatous infection, stable. No XXXX focal airspace consolidation. No pleural effusion, no pneumothorax. Bony structures unremarkable.',
#   'impression': 'No acute cardiopulmonary abnormality. Prior granulomatous infection.',
#   'tags_manual': ['Granulomatous Disease', 'Calcinosis/bilateral/scattered'],
#   'tags_mti': ['granulomatous infection'],
#   'images': ['CXR1110_IM-0076-1001.png', 'CXR1110_IM-0076-2001.png']},
#  {'id': 'CXR202',
#   'comparison': 'Chest x-XXXX XXXX',
#   'indication': 'Back and chest pain.',
#   'findings': 'AP and lateral view of the chest.',
#   'impression': '1. Cardiomegaly with central vascular congestion and increased interstitial opacities suggesting mild interstitial pulmonary edema. 2. Small bilateral pleural effusions. 3. No visible pneumothorax.',
#   'tags_manual': ['Cardiomegaly',
#    'Pulmonary Congestion',
#    'Opacity/lung/interstitial',
#    'Pleural Effusion/bilateral/small'],
#   'tags_mti': ['bilateral pleural effusion',
#    'interstitial pulmonary edema',
#    'opacity',
#    'Cardiomegaly',
#    'Pleural Effusion',
#    'Pulmonary Edema'],
#   'images': ['CXR202_IM-0667-4004.png', 'CXR202_IM-0667-1001.png']},
#  {'id': 'CXR2428',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old male, pain',
#   'findings': 'Lungs mildly hyperinflated with flattened posterior diaphragm and increased retrosternal airspace. No focal alveolar consolidation, no definite pleural effusion seen. Left hilar calcifications and dense left lower lobe nodules suggest a previous granulomatous process. Overall heart size within normal limits with prominent right atrial convexity, no typical findings of pulmonary edema. No pneumothorax.',
#   'impression': '1. Hyperinflated lungs, air trapping versus inspiratory XXXX. 2. Question mild right atrial enlargement, no findings to suggest pulmonary edema.',
#   'tags_manual': ['Lung/hyperdistention/mild',
#    'Diaphragm/posterior/flattened',
#    'Calcinosis/lung/hilum/left',
#    'Nodule/lung/lower lobe/left/multiple',
#    'Density/lung/lower lobe/left/round/multiple',
#    'Heart Atria/right/prominent'],
#   'tags_mti': ['air trapping',
#    'hilar calcification',
#    'right atrial enlargement'],
#   'images': ['CXR2428_IM-0970-3001.png', 'CXR2428_IM-0970-1001.png']},
#  {'id': 'CXR3748',
#   'comparison': 'XXXX, XXXX.',
#   'indication': 'Pain behind right shoulder XXXX starting today. MRI of right shoulder in XXXX. Nausea.',
#   'findings': 'The cardiomediastinal silhouette and pulmonary vasculature are within normal limits in size. There is minimal XXXX atelectasis or scar in the left lung base. The lungs are clear of focal airspace disease, pneumothorax, or pleural effusion. There are no acute bony findings.',
#   'impression': 'No acute cardiopulmonary findings. .',
#   'tags_manual': ['Pulmonary Atelectasis/base/left/mild',
#    'Cicatrix/lung/base/left/mild'],
#   'tags_mti': ['atelectases', 'scar', 'Atelectasis'],
#   'images': ['CXR3748_IM-1874-1001.png', 'CXR3748_IM-1874-2001.png']},
#  {'id': 'CXR2327',
#   'comparison': 'PA and lateral views of the chest on XXXX, XXXX CT scan of the thorax on XXXX, XXXX.',
#   'indication': 'Decreased oxygen saturation.',
#   'findings': 'There has been interval development of a large right-sided pleural effusion. The left lung is clear. There is no pneumothorax. Heart size mediastinal contours are within normal limits. XXXX deformity is noted at the upper thoracic vertebral body.',
#   'impression': 'Interval development of large right-sided pleural effusion. XXXX deformity noted at the upper thoracic vertebral body XXXX relates to XXXX deformity described on previous CT scan.',
#   'tags_manual': ['Pleural Effusion/right/large',
#    'Deformity/thoracic vertebrae'],
#   'tags_mti': ['deformity',
#    'right-sided pleural effusion',
#    'Pleural Effusion'],
#   'images': ['CXR2327_IM-0898-1001.png', 'CXR2327_IM-0898-2001.png']},
#  {'id': 'CXR3287',
#   'comparison': 'CT chest XXXX',
#   'indication': 'Abnormal findings of previous studies XXXX in XXXX.',
#   'findings': 'Heart size and mediastinal contour normal. There is a 2.5 cm vague nodular density in the right mid lung, probably within the middle lobe given the opacification on the lateral view. There is a subtle left retrocardiac density also noted, with obscuration of aortic contour. No pleural effusions or pneumothorax.',
#   'impression': 'Right midlung and left basilar airspace densities. The most recent study is not available for comparison. Recommend further evaluation with XXXX.',
#   'tags_manual': ['Density/lung/middle lobe/right/round',
#    'Aorta/obscured',
#    'Density/lung/base/left/retrocardiac'],
#   'tags_mti': [],
#   'images': ['CXR3287_IM-1568-2002.png', 'CXR3287_IM-1568-3003.png']},
#  {'id': 'CXR3424',
#   'comparison': 'None.',
#   'indication': 'XXXX-year-old female with COPD and left pleuritic chest pain.',
#   'findings': 'The heart size is normal. The mediastinal contour is within normal limits. There are multiple calcified granulomas within the left lower lobe. The lungs are free of any focal infiltrates. There are no nodules or masses. No visible pneumothorax. No visible pleural fluid. The XXXX are grossly normal. There is no visible free intraperitoneal air under the diaphragm.',
#   'impression': 'No acute radiographic cardiopulmonary process.',
#   'tags_manual': ['Calcified Granuloma/lung/lower lobe/left/multiple'],
#   'tags_mti': ['calcified granuloma'],
#   'images': ['CXR3424_IM-1656-1001.png', 'CXR3424_IM-1656-2001.png']},
#  {'id': 'CXR2551',
#   'comparison': 'XXXX',
#   'indication': 'Palpitations',
#   'findings': 'Heart size and mediastinal contour are normal. Pulmonary vascularity is normal. Lungs are clear. No pleural effusions or pneumothoraces.',
#   'impression': 'No acute cardiopulmonary process.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2551_IM-1058-1001.png', 'CXR2551_IM-1058-2001.png']},
#  {'id': 'CXR416',
#   'comparison': None,
#   'indication': 'XXXX-year-old female, XXXX',
#   'findings': 'Heart size within normal limits, stable mediastinal and hilar contours. No focal alveolar consolidation, no definite pleural effusion seen. No typical findings of pulmonary edema.',
#   'impression': 'No acute findings',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR416_IM-2059-1001.png', 'CXR416_IM-2059-2001.png']},
#  {'id': 'CXR2015',
#   'comparison': 'XXXX.',
#   'indication': 'XXXX and hypoxia.',
#   'findings': 'Heart size and mediastinal contours appear within normal limits. Pulmonary vascularity is within normal limits. No focal consolidation, suspicious pulmonary opacity, pneumothorax or definite pleural effusion. Visualized osseous structures appear intact.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2015_IM-0664-1001.png', 'CXR2015_IM-0664-2001.png']},
#  {'id': 'CXR3911',
#   'comparison': None,
#   'indication': 'altered mental status.',
#   'findings': None,
#   'impression': 'Heart size is normal and lungs are clear. No pneumonia or effusion. No nodules or masses.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR3911_IM-1987-1001.png', 'CXR3911_IM-1987-2001.png']},
#  {'id': 'CXR1477',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old female, pain',
#   'findings': 'Heart size within normal limits. No focal alveolar consolidation, no definite pleural effusion seen. No typical findings of pulmonary edema. No pneumothorax.',
#   'impression': 'No acute cardiopulmonary findings',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1477_IM-0309-1001.png', 'CXR1477_IM-0309-2001.png']},
#  {'id': 'CXR932',
#   'comparison': 'None.',
#   'indication': None,
#   'findings': 'No gross consolidation, atelectasis or infiltrate. No pleural fluid collection or pneumothorax. Cardiomediastinal silhouette is within normal limits. XXXX XXXX is intact.',
#   'impression': '1. Negative for acute cardiopulmonary findings.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR932_IM-2430-3001.png',
#    'CXR932_IM-2430-2001.png',
#    'CXR932_IM-2430-4004.png']},
#  {'id': 'CXR3585',
#   'comparison': 'XXXX, XXXX. No change in the levoscoliosis of the thoracolumbar spine. Both lungs remain clear and expanded. Heart and mediastinum are normal.',
#   'indication': 'PAIN',
#   'findings': None,
#   'impression': 'No active cardiopulmonary disease.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR3585_IM-1763-1001.png', 'CXR3585_IM-1763-2001.png']},
#  {'id': 'CXR3155',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old male, pain',
#   'findings': 'Heart size mildly enlarged with enlarged right atrium. No focal alveolar consolidation, no definite pleural effusion seen. No pneumothorax.',
#   'impression': 'Cardiomegaly, no acute pulmonary findings',
#   'tags_manual': ['Cardiomegaly/mild', 'Heart Atria/right/enlarged'],
#   'tags_mti': ['Cardiomegaly'],
#   'images': ['CXR3155_IM-1486-2001.png', 'CXR3155_IM-1486-1001.png']},
#  {'id': 'CXR1278',
#   'comparison': 'None',
#   'indication': 'Bilateral breast cancer',
#   'findings': 'The heart is normal in size. The mediastinum is unremarkable. The lungs are clear.',
#   'impression': 'No acute disease.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1278_IM-0185-1001.png', 'CXR1278_IM-0185-1002.png']},
#  {'id': 'CXR2184',
#   'comparison': 'Abdomen and pelvis CT from XXXX.',
#   'indication': 'XXXX-year-old woman with XXXX and leukocytosis.',
#   'findings': 'The heart is mildly enlarged. Mediastinal contour and pulmonary vascularity are within normal limits. There are streaky left basilar airspace opacities, compatible with atelectasis as seen on comparison abdomen and pelvis CT. There is a left upper lung granuloma. Otherwise, no focal consolidation, large pleural effusion, or pneumothorax. XXXX appear intact.',
#   'impression': 'Left basilar atelectasis. No acute cardiopulmonary abnormalities.',
#   'tags_manual': ['Cardiomegaly/mild',
#    'Opacity/lung/base/left/streaky',
#    'Pulmonary Atelectasis/base/left',
#    'Granuloma/lung/upper lobe/left'],
#   'tags_mti': ['atelectases', 'lung granuloma', 'opacity', 'Atelectasis'],
#   'images': ['CXR2184_IM-0795-2001.png', 'CXR2184_IM-0795-1001.png']},
#  {'id': 'CXR1916',
#   'comparison': 'Chest radiograph XXXX.',
#   'indication': 'COPD',
#   'findings': 'There is stable left costophrenic XXXX blunting. The patient has undergone prior left lobectomy. There are chronic appearing right basilar interstitial markings. Heart size normal. No visualized pneumothorax. There is stable appearing left upper and right upper lobe bullous disease.',
#   'impression': '1. No acute cardiopulmonary findings. 2. Unchanged chronic appearance of the left lung.',
#   'tags_manual': ['Costophrenic Angle/left/blunted',
#    'Pneumonectomy/lung/left',
#    'Markings/lung/base/right/interstitial/chronic',
#    'Blister/lung/upper lobe/bilateral'],
#   'tags_mti': ['lobectomy', 'Pneumonectomy'],
#   'images': ['CXR1916_IM-0595-1001.png', 'CXR1916_IM-0595-2001.png']},
#  {'id': 'CXR2376',
#   'comparison': 'Chest x-XXXX XXXX.',
#   'indication': 'XXXX x1 XXXX.',
#   'findings': 'The XXXX examination consists of frontal and lateral radiographs of the chest. The cardiomediastinal contours, lungs, pleura, osseous structures and visualized upper abdomen are normal.',
#   'impression': 'Unremarkable radiographs of the chest.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR2376_IM-0936-1001.png', 'CXR2376_IM-0936-2001.png']},
#  {'id': 'CXR3546',
#   'comparison': None,
#   'indication': 'This is a XXXX-year-old XXXX with a history of congestive heart failure and back pain.',
#   'findings': 'Unchanged cardiomegaly. There is continued interstitial prominence bilaterally. Unchanged vascular appearance. There is patchy retrocardiac opacity. Negative for pneumothorax.',
#   'impression': 'Unchanged appearance of the chest with interstitial prominence the differential of which is XXXX but could include interstitial edema, infectious process or interstitial disease.',
#   'tags_manual': ['Cardiomegaly',
#    'Lung/bilateral/interstitial/prominent',
#    'Opacity/retrocardiac/patchy'],
#   'tags_mti': ['edemas',
#    'interstitial disease',
#    'opacity',
#    'Edema',
#    'Pulmonary Edema'],
#   'images': ['CXR3546_IM-1738-2001.png', 'CXR3546_IM-1738-4004.png']},
#  {'id': 'CXR3000',
#   'comparison': 'CT chest XXXX',
#   'indication': 'XXXX-year-old male with history renal XXXX, 593.9. Evaluate for metastatic disease.',
#   'findings': 'There are multiple bilateral pulmonary nodules. For example, there is a 12 mm left lower lobe nodule, XXXX seen on the frontal view. There is no pleural effusion or pneumothorax. Heart size is within normal limits. The left hilar contour is prominent. There are diffuse degenerative changes of the spine.',
#   'impression': '1. Multiple bilateral pulmonary nodules, concerning for metastatic disease. 2. Prominent left hilum. After correlation with the XXXX scan performed today, findings XXXX reflect enlargement of the left pulmonary artery.',
#   'tags_manual': ['Nodule/lung/bilateral/multiple',
#    'Nodule/lung/lower lobe/left',
#    'Lung/hilum/left/prominent',
#    'Spine/degenerative/diffuse',
#    'Pulmonary Artery/left/enlarged'],
#   'tags_mti': ['degenerative change',
#    'nodule',
#    'Multiple Pulmonary Nodules',
#    'Pulmonary Artery'],
#   'images': ['CXR3000_IM-1386-0001-0002.png',
#    'CXR3000_IM-1386-0001-0001.png']},
#  {'id': 'CXR2180',
#   'comparison': None,
#   'indication': 'preop kidney transplant. No chest complaints',
#   'findings': None,
#   'impression': 'Marked increase in heart size. Cardiomegaly. Question pericardial effusion. Stable 1.5 cm nodule left mid chest, XXXX a granuloma. Lungs are clear. No effusion. Stable left hilar lymphadenopathy.',
#   'tags_manual': ['Cardiomegaly/severe',
#    'Nodule/thorax/left',
#    'Granuloma/thorax/left',
#    'Lung/hilum/lymph nodes/left/enlarged'],
#   'tags_mti': ['pericardial effusion',
#    'Pericardial Effusion',
#    'granuloma',
#    'hilar lymphadenopathy',
#    'nodule',
#    'Cardiomegaly',
#    'Granuloma'],
#   'images': ['CXR2180_IM-0793-2001.png', 'CXR2180_IM-0793-1001.png']},
#  {'id': 'CXR432',
#   'comparison': 'None.',
#   'indication': 'XXXX-year-old female, XXXX, nonsmoker.',
#   'findings': 'The cardiomediastinal silhouette is within normal limits for size and contour. The lungs are normally inflated without evidence of focal airspace disease, pleural effusion, or pneumothorax. Cholecystectomy clips overlie the right upper quadrant. No acute bone abnormality.',
#   'impression': 'No acute cardiopulmonary process.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR432_IM-2072-1001.png', 'CXR432_IM-2072-1002.png']},
#  {'id': 'CXR2227',
#   'comparison': 'XXXX at XXXX dated XXXX',
#   'indication': 'Chest pain, shortness of breath, on home oxygen, history of sarcoidosis and smoking',
#   'findings': "There is increasing primarily basilar interstitial reticular opacity. Lung volumes are low. There are no focal airspace opacities to suggest lobar pneumonia. Heart size appears normal. The thoracic aorta is calcified. Since the prior study, there has been placement of an electronic cardiac device overlying the left chest wall, the distal leads overlying the right heart. There's no pneumothorax.",
#   'impression': '1. Findings consistent with worsening interstitial lung disease. High resolution XXXX is recommended to confirm this. Prior XXXX from XXXX reveals no evidence of interstitial lung disease.',
#   'tags_manual': ['Opacity/lung/base/interstitial/reticular',
#    'Lung/hypoinflation',
#    'Calcinosis/aorta, thoracic',
#    'Implanted Medical Device/left',
#    'Lung Diseases, Interstitial'],
#   'tags_mti': ['interstitial lung disease',
#    'opacity',
#    'electronic cardiac device',
#    'Interstitial Lung Disease',
#    'Thoracic Aorta'],
#   'images': ['CXR2227_IM-0831-2001.png']},
#  {'id': 'CXR3824',
#   'comparison': 'XXXX',
#   'indication': 'Shortness of breath',
#   'findings': None,
#   'impression': '1. Patchy bilateral opacities, primarily in the lung bases, whose features are most consistent with pneumonia. Aspiration or edema are also possible but less XXXX. 2. XXXX lung volumes 3. No pneumothorax',
#   'tags_manual': ['Opacity/lung/base/bilateral/patchy',
#    'Pneumonia/base/bilateral/patchy',
#    'Lung/hypoinflation'],
#   'tags_mti': ['aspiration',
#    'edemas',
#    'opacity',
#    'pneumonia',
#    'Edema',
#    'Pneumonia'],
#   'images': ['CXR3824_IM-1931-1001.png']},
#  {'id': 'CXR966',
#   'comparison': 'Chest x-XXXX, XXXX, XXXX.',
#   'indication': 'This is a XXXX-year-old female patient with shortness of breath and dyspnea.',
#   'findings': None,
#   'impression': 'The cardiac silhouette is normal in size and configuration. The mediastinum and perihilar structures appear to be are unremarkable. An element of atelectasis and infiltrate is noted involving the right upper lobe. In addition, subsegmental atelectatic change is present overlying the left ventricle. No pneumothorax is identified. The osseous structures appear to be unremarkable. Incidental note is XXXX of nipple XXXX.',
#   'tags_manual': ['Pulmonary Atelectasis/upper lobe/right',
#    'Infiltrate/lung/upper lobe/right',
#    'Pulmonary Atelectasis/left',
#    'Foreign Bodies/breast'],
#   'tags_mti': ['atelectases', 'infiltrates', 'Atelectasis'],
#   'images': ['CXR966_IM-2456-1001.png', 'CXR966_IM-2456-2001.png']},
#  {'id': 'CXR2462',
#   'comparison': 'XXXX, XXXX.',
#   'indication': 'XXXX-year-old male with history of XXXX.',
#   'findings': 'There is stable cardiomegaly. Aorta is calcified and tortuous. There are multiple pleural calcifications XXXX representing prior asbestos exposure. These appear unchanged. There is no pneumothorax, pleural effusion, or XXXX focal airspace consolidation.',
#   'impression': '1. Cardiomegaly and findings of prior asbestos exposure without interval acute cardiopulmonary findings.',
#   'tags_manual': ['Cardiomegaly',
#    'Calcinosis/aorta',
#    'Aorta/tortuous',
#    'Calcinosis/pleura/multiple'],
#   'tags_mti': ['asbestos exposure',
#    'pleural calcification',
#    'Asbestosis',
#    'Cardiomegaly'],
#   'images': ['CXR2462_IM-0995-3001.png', 'CXR2462_IM-0995-1001.png']},
#  {'id': 'CXR1500',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'XXXX loss, tobacco history',
#   'findings': 'Normal heart size. Aortic calcification. Granulomatous nodule left midlung, stable. No acute pulmonary abnormalities. Thoracic spondylosis.',
#   'impression': 'No acute pulmonary findings.',
#   'tags_manual': ['Calcinosis/aorta',
#    'Granuloma/lung/lingula',
#    'Spondylosis/thoracic vertebrae',
#    'Nodule/lung/lingula'],
#   'tags_mti': ['aortic calcifications', 'nodule', 'Calcinosis'],
#   'images': ['CXR1500_IM-0326-10001.png',
#    'CXR1500_IM-0326-11001.png',
#    'CXR1500_IM-0326-9001.png']},
#  {'id': 'CXR71',
#   'comparison': 'None.',
#   'indication': 'XXXX year old right shoulder and back pain after a XXXX vehicle XXXX..',
#   'findings': 'The heart is upper limits of normal in size. The lungs are clear, without evidence of infiltrate. There is no pneumothorax or effusion.',
#   'impression': 'No acute cardiopulmonary disease.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR71_IM-2273-1001.png']},
#  {'id': 'CXR382',
#   'comparison': 'CT chest with contrast, dated XXXX.',
#   'indication': 'XXXX year-old female with hemoptysis. History of sarcoidosis.',
#   'findings': 'Stable, normal cardiac size, mediastinum, and central pulmonary vasculature. Marked bullous emphysematous changes and traction bronchiectasis, again most notable involving the bilateral upper lobes. Stable prominent ovoid opacity (4.3 x 2.8 XXXX) XXXX a large left upper lobe XXXX, XXXX reflecting a superimposed aspergilloma-as more readily demonstrated on the previous CT chest study from XXXX. No XXXX areas of alveolar airspace consolidation are identified. No evidence of pleural effusion or pneumothorax.',
#   'impression': '1. Marked bullous emphysematous changes and traction bronchiectasis, again most notable involving the bilateral upper lobes. Stable suspected superimposed left upper lobe aspergilloma - as more readily demonstrated on the previous CT chest study from XXXX.',
#   'tags_manual': ['Bullous Emphysema/lung/upper lobe/bilateral/severe',
#    'Bronchiectasis/upper lobe/bilateral',
#    'Opacity/lung/upper lobe/left/prominent'],
#   'tags_mti': ['aspergilloma',
#    'opacity',
#    'traction bronchiectasis',
#    'Bronchiectasis',
#    'Pulmonary Aspergillosis'],
#   'images': ['CXR382_IM-1927-1001.png', 'CXR382_IM-1927-2001.png']},
#  {'id': 'CXR3816',
#   'comparison': 'XXXX.',
#   'indication': 'Kidney cancer.',
#   'findings': 'Heart size is at the upper limits of normal. The pulmonary vascularity appears within normal limits. The lungs are free of focal airspace disease. No pleural effusion or pneumothorax is seen. Degenerative changes are present in the spine. No non-calcified nodules are identified.',
#   'impression': '1. No evidence of active disease.',
#   'tags_manual': ['Spine/degenerative'],
#   'tags_mti': ['degenerative change'],
#   'images': ['CXR3816_IM-1925-1001.png', 'CXR3816_IM-1925-2001.png']},
#  {'id': 'CXR1778',
#   'comparison': None,
#   'indication': None,
#   'findings': None,
#   'impression': None,
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1778_IM-0509-2001.png', 'CXR1778_IM-0509-1001.png']},
#  {'id': 'CXR3293',
#   'comparison': 'None',
#   'indication': 'XXXXyo POD#1 XXXX XXXX with XXXX, left basilar crackles on exam',
#   'findings': 'Lung volumes are low. The heart is large, and the pulmonary XXXX are engorged. Bibasilar interstitial infiltrates are present. Bilateral costophrenic XXXX blunting is present.',
#   'impression': 'Congestive heart failure with bibasilar pulmonary interstitial edema and bilateral pleural fluid.',
#   'tags_manual': ['Lung/hypoinflation',
#    'Cardiomegaly',
#    'Infiltrate/lung/base/bilateral/interstitial',
#    'Costophrenic Angle/bilateral/blunted',
#    'Heart Failure',
#    'Pulmonary Edema/base/bilateral/interstitial',
#    'Pleural Effusion/bilateral',
#    'Pulmonary Congestion'],
#   'tags_mti': ['congestive heart failure',
#    'edemas',
#    'infiltrates',
#    'pleural fluid',
#    'Congestive Heart Failure',
#    'Edema',
#    'Pleural Effusion'],
#   'images': []},
#  {'id': 'CXR3394',
#   'comparison': 'None.',
#   'indication': 'Preop anesthesia XXXX for temporal cancer.',
#   'findings': 'The cardiac contours are normal. XXXX scarring left base. The lungs are clear. Thoracic spondylosis.',
#   'impression': 'No acute preoperative process.',
#   'tags_manual': ['Cicatrix/lung/base/left', 'Spondylosis/thoracic vertebrae'],
#   'tags_mti': ['scarring', 'Scarring', 'Thoracic Spondylosis'],
#   'images': ['CXR3394_IM-1638-3001.png', 'CXR3394_IM-1638-1001.png']},
#  {'id': 'CXR712',
#   'comparison': None,
#   'indication': 'XXXX-year-old male with XXXX and bronchitis.',
#   'findings': 'The lungs are mildly hyperexpanded. There is no focal airspace consolidation to suggest pneumonia. No pleural effusion or pneumothorax. Normal heart size and mediastinal contour.',
#   'impression': 'No acute abnormality demonstrated.',
#   'tags_manual': ['Lung/hyperdistention/mild'],
#   'tags_mti': [],
#   'images': ['CXR712_IM-2274-0001-0002.png',
#    'CXR712_IM-2274-0001-0003.png',
#    'CXR712_IM-2274-0001-0001.png']},
#  {'id': 'CXR1148',
#   'comparison': 'None.',
#   'indication': 'Chest pain',
#   'findings': 'Cardiac and mediastinal contours are within normal limits. The lungs are clear. Bony structures are intact.',
#   'impression': 'Negative chest x-XXXX.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1148_IM-0100-2001.png', 'CXR1148_IM-0100-1001.png']},
#  {'id': 'CXR3557',
#   'comparison': 'XXXX.',
#   'indication': 'Chest pain.',
#   'findings': 'Left PICC line and NG tube remain in XXXX. Heart size and vascularity appear within normal limits. The lungs are free of focal airspace disease. Small bilateral pleural effusions are present. No pneumothorax is noted.',
#   'impression': '1. Small bilateral pleural effusions.',
#   'tags_manual': ['Catheters, Indwelling/left',
#    'Tube, Inserted',
#    'Pleural Effusion/bilateral/small'],
#   'tags_mti': ['bilateral pleural effusion', 'picc line', 'Pleural Effusion'],
#   'images': ['CXR3557_IM-1742-0001-0001.png',
#    'CXR3557_IM-1742-0001-0002.png']},
#  {'id': 'CXR2139',
#   'comparison': 'None.',
#   'indication': 'Chest pain, nonproductive XXXX. Cutaneous XXXX.',
#   'findings': 'The lungs and pleural spaces show no acute abnormality. Calcified right hilar lymph XXXX. Heart size is enlarged, pulmonary vascularity within normal limits. XXXX sternotomy XXXX and prosthetic aortic valve noted.',
#   'impression': '1. No acute pulmonary abnormality. 2. Mild cardiomegaly without pulmonary edema.',
#   'tags_manual': ['Cardiomegaly/mild',
#    'Calcinosis/lung/hilum/lymph nodes/right',
#    'Implanted Medical Device/aortic valve'],
#   'tags_mti': ['sternotomy', 'Cardiomegaly'],
#   'images': ['CXR2139_IM-0760-1001.png', 'CXR2139_IM-0760-2001.png']},
#  {'id': 'CXR3493',
#   'comparison': 'None',
#   'indication': 'XXXX, edema in XXXX',
#   'findings': 'Heart size is within normal limits. Trachea is midline. The lung volumes are slightly on the low side. Lungs are otherwise clear without pleural effusion or pneumothorax. No focal consolidations. No bony or soft tissue abnormalities.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['Lung/hypoinflation/mild'],
#   'tags_mti': [],
#   'images': ['CXR3493_IM-1698-1001.png', 'CXR3493_IM-1698-1002.png']},
#  {'id': 'CXR501',
#   'comparison': 'Chest CT dated XXXX',
#   'indication': 'XXXX',
#   'findings': None,
#   'impression': '1. There is minimal streaky opacity in the posterior lungs, possibly cyst, scarring, or pneumonia. 2. Heart size and pulmonary XXXX appear normal 3. Mediastinal contours are normal',
#   'tags_manual': ['Opacity/lung/posterior/streaky/mild'],
#   'tags_mti': ['cyst',
#    'opacity',
#    'pneumonia',
#    'scarring',
#    'Cicatrix',
#    'Cyst',
#    'Pneumonia'],
#   'images': ['CXR501_IM-2120-1001.png', 'CXR501_IM-2120-2001.png']},
#  {'id': 'CXR2570',
#   'comparison': 'XXXX, XXXX.',
#   'indication': 'XXXX, hypertension.',
#   'findings': 'There has been interval increase in size of the cardiac silhouette from XXXX. The cardiac fluid is now mildly enlarged. Pulmonary vasculature is increased with mildly increased interstitial markings and fissural thickening, suggesting mild pulmonary edema. There is no focal airspace disease, pneumothorax, or large pleural effusion. Descending thoracic aorta is tortuous. There are no acute bony findings.',
#   'impression': 'Cardiomegaly which appears XXXX from XXXX with probable mild pulmonary edema. .',
#   'tags_manual': ['Cardiac Shadow/enlarged',
#    'Pericardial Effusion/mild',
#    'Pulmonary Congestion',
#    'Markings/lung/interstitial',
#    'Aorta, Thoracic/tortuous',
#    'Cardiomegaly',
#    'Pulmonary Edema/mild',
#    'Thickening/pleura'],
#   'tags_mti': ['Cardiomegaly', 'Pulmonary Edema'],
#   'images': ['CXR2570_IM-1073-1001.png', 'CXR2570_IM-1073-2001.png']},
#  {'id': 'CXR2670',
#   'comparison': 'None available.',
#   'indication': 'XXXX-year-old male with worsening dyspnea over 2 months.',
#   'findings': 'Hyperexpanded lungs with flattened hemidiaphragms, consistent with emphysema. There is streaky airspace opacities in the left suprahilar and lingular regions. No pneumothorax or effusions. Mild bilateral costophrenic XXXX blunting XXXX represents pleural thickening and scarring. Degenerative changes of the thoracic spine.',
#   'impression': 'Emphysematous changes with streaky opacities in the left perihilar and lingular regions, XXXX focal atelectasis and scarring.',
#   'tags_manual': ['Lung/hyperdistention',
#    'Diaphragm/bilateral/flattened',
#    'Pulmonary Emphysema',
#    'Opacity/lung/lingula/streaky',
#    'Opacity/lung/hilum/left/streaky',
#    'Costophrenic Angle/bilateral/blunted/mild',
#    'Thickening/pleura/bilateral',
#    'Cicatrix/pleura/bilateral',
#    'Thoracic Vertebrae/degenerative',
#    'Pulmonary Atelectasis'],
#   'tags_mti': ['degenerative change',
#    'emphysemas',
#    'focal atelectasis',
#    'opacity',
#    'pleural thickening',
#    'scarring',
#    'Diaphragm',
#    'Emphysema',
#    'Pulmonary Atelectasis',
#    'Pulmonary Emphysema',
#    'Scarring'],
#   'images': ['CXR2670_IM-1148-1001.png', 'CXR2670_IM-1148-1002.png']},
#  {'id': 'CXR443',
#   'comparison': None,
#   'indication': 'Positive PPD',
# ...
#  {'id': 'CXR3971',
#   'comparison': 'AP portable chest radiograph XXXX; PA and lateral chest radiographs XXXX.',
#   'indication': 'XXXX-year-old male with chest pain.',
#   'findings': 'The heart size and cardiomediastinal silhouette are normal. There is no focal airspace opacity, pleural effusion or pneumothorax. The bony structures are normal.',
#   'impression': 'No acute cardiopulmonary finding.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR3971_IM-2031-2001.png',
#    'CXR3971_IM-2031-3001.png',
#    'CXR3971_IM-2031-1001.png']},
#  {'id': 'CXR318',
#   'comparison': 'PA and lateral views of the chest on XXXX, XXXX.',
#   'indication': 'Dyspnea',
#   'findings': 'Lungs are clear bilaterally. Cardiac and mediastinal silhouettes are normal. Pulmonary vasculature is normal. No pneumothorax or pleural effusion. No acute bony abnormality.',
#   'impression': 'No acute cardiopulmonary abnormality.',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR318_IM-1500-1001.png', 'CXR318_IM-1500-2001.png']},
#  {'id': 'CXR3935',
#   'comparison': None,
#   'indication': 'Hemorrhage, post-op change.',
#   'findings': 'Left PICC line remains in XXXX. The tip projects over the upper SVC. It has moved outward since the previous study. The heart size and pulmonary vascularity appear within normal limits. Previously present left base airspace disease has cleared. There is blunting of the right costophrenic XXXX which may represent small amount of pleural effusion or pleural reaction. Some scattered bandlike opacities are present which appear to represent scars. Degenerative changes are present in the right shoulder.',
#   'impression': '1. Blunting of the right costophrenic XXXX. This may represent pleural effusion or pleural reaction. 2. Clearing of left base airspace disease. 3. Outward XXXX of PICC line. Tip now projects over upper SVC.',
#   'tags_manual': ['Catheters, Indwelling/left',
#    'Costophrenic Angle/right/blunted',
#    'Opacity/scattered/multiple',
#    'Cicatrix/scattered/multiple',
#    'Shoulder/right/degenerative'],
#   'tags_mti': ['degenerative change',
#    'opacity',
#    'pleural effusions',
#    'scar',
#    'picc line',
#    'Pleural Effusion'],
#   'images': ['CXR3935_IM-2006-1001.png', 'CXR3935_IM-2006-2001.png']},
#  {'id': 'CXR825',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'Shortness of breath',
#   'findings': None,
#   'impression': 'Patchy bilateral airspace disease with pulmonary XXXX, XXXX a combination of atelectasis and consolidation. Borderline cardiac enlargement. Tracheostomy tube tip 6.4 cm above the carina.',
#   'tags_manual': ['Airspace Disease/lung/bilateral/patchy',
#    'Pulmonary Atelectasis/bilateral',
#    'Consolidation/lung/bilateral',
#    'Cardiomegaly/borderline',
#    'Tube, Inserted/trachea, carina'],
#   'tags_mti': ['atelectases',
#    'tracheostomies',
#    'Atelectasis',
#    'surgery',
#    'Trachea',
#    'Tracheostomy'],
#   'images': ['CXR825_IM-2355-2001.png', 'CXR825_IM-2355-1001.png']},
#  {'id': 'CXR1940',
#   'comparison': 'PA and lateral views of the chest dated XXXX.',
#   'indication': 'XXXX-year-old female, history of breast cancer, no chest complaints.',
#   'findings': 'Postsurgical changes noted overlying the left axilla. No focal areas of consolidation. No suspicious pulmonary opacities. Heart size within normal limits. No pleural effusions. No evidence of pneumothorax.',
#   'impression': 'No acute cardiopulmonary abnormality. .',
#   'tags_manual': ['normal'],
#   'tags_mti': [],
#   'images': ['CXR1940_IM-0610-2002.png', 'CXR1940_IM-0610-3003.png']},
#  {'id': 'CXR874',
#   'comparison': 'Yesterday.',
#   'indication': 'XXXX-year-old with ICD implantation.',
#   'findings': 'There is mild hyperinflation. There is no focal consolidation. There is no pneumothorax or large pleural effusion. The cardiomediastinal contours are grossly unremarkable. The heart size is within normal limits. cardiac XXXX generator overlies the left upper thorax with XXXX XXXX tips overlying the right atrium and ventricles.',
#   'impression': 'No acute cardiopulmonary findings. .',
#   'tags_manual': ['Lung/hyperdistention/mild',
#    'Implanted Medical Device/left'],
#   'tags_mti': ['hyperinflation', 'tips', 'Heart Ventricles', 'Right Atrium'],
#   'images': ['CXR874_IM-2392-2001.png']},
#  {'id': 'CXR3912',
#   'comparison': 'XXXX.',
#   'indication': 'XXXX-year-old male, and dizziness.',
#   'findings': 'Examination is somewhat limited, the costophrenic XXXX and posterior costophrenic sulci are excluded. Patient is rotated to the right. Heart size upper limits normal, but stable. Mediastinal contour is grossly unremarkable. Lung parenchyma is clear, no focal airspace consolidation. No large effusion, no visible pneumothorax within the limits of the study.',
#   'impression': '1. Exam somewhat limited, costophrenic XXXX excluded. 2. Stable mild cardiomegaly. 3. Clear lungs.',
#   'tags_manual': ['Technical Quality of Image Unsatisfactory ',
#    'Costophrenic Angle/obscured',
#    'Costophrenic Angle/sulcus/posterior/obscured',
#    'Cardiomegaly/mild'],
#   'tags_mti': ['Cardiomegaly'],
#   'images': ['CXR3912_IM-1988-2001-0002.png',
#    'CXR3912_IM-1988-1001.png',
#    'CXR3912_IM-1988-2001-0001.png']},
#  {'id': 'CXR3529',
#   'comparison': 'XXXX.',
#   'indication': 'Status post XXXX surgery XXXX',
#   'findings': 'Status post midline sternotomy with intact XXXX XXXX. Stable mild cardiomegaly. Normal lung vascularity. The lungs are clear.',
#   'impression': 'Stable postop changes with stable mild cardiomegaly and normal lung vascularity.',
#   'tags_manual': ['Cardiomegaly/mild'],
#   'tags_mti': ['sternotomy', 'Cardiomegaly'],
#   'images': ['CXR3529_IM-1725-2001.png', 'CXR3529_IM-1725-1001.png']},
#  {'id': 'CXR3091',
#   'comparison': 'AP chest dated XXXX.',
#   'indication': 'XXXX-year-old with chest congestion evaluate for pneumonia.',
#   'findings': 'The heart size is mildly enlarged. The patient is post aortic valve replacement. The XXXX sternotomy XXXX are intact. The pulmonary XXXX and mediastinum are within normal limits. There is no pleural effusion or pneumothorax. There is no focal air space opacity to suggest a pneumonia. There mild degenerative changes of the spine.',
#   'impression': 'No acute cardiopulmonary disease. Critical result notification documented through Primordial.',
#   'tags_manual': ['Cardiomegaly/mild',
#    'Implanted Medical Device/aortic valve',
#    'Spine/degenerative'],
#   'tags_mti': ['degenerative change',
#    'aortic valve replacement',
#    'sternotomy',
#    'Aortic Valve',
#    'Heart Valve Prosthesis',
#    'Heart Valve Prosthesis Implantation'],
#   'images': ['CXR3091_IM-1445-2001.png', 'CXR3091_IM-1445-1001.png']},
#  {'id': 'CXR2126',
#   'comparison': 'XXXX hours',
#   'indication': 'Status post cardiac valve replacement and CABG.',
#   'findings': None,
#   'impression': 'Interval improvement/resolution right patchy lateral base opacity. There is continued XXXX density in the right lateral and left base of the chest with minimal tenting of the lateral right hemidiaphragm . Costophrenic XXXX blunting may persist but the left costophrenic XXXX is clipped from view. There is a right middle base calcific nodular density XXXX from old granulomatous disease. Mild left apical pleural thickening. XXXX XXXX and valve XXXX. Probable prominent epicardial fat pads on either side. Thoracic spine DISH.',
#   'tags_manual': ['Density/thorax/right',
#    'Density/thorax/base/left',
#    'Diaphragm/right/elevated/mild',
#    'Costophrenic Angle/left/obscured',
#    'Technical Quality of Image Unsatisfactory ',
#    'Calcinosis/lung/middle lobe/right/round',
#    'Density/lung/middle lobe/right/round',
#    'Granulomatous Disease',
#    'Thickening/pleura/apex/left/mild',
#    'Epicardial Fat/bilateral/prominent',
#    'Hyperostosis, Diffuse Idiopathic Skeletal/thoracic vertebrae'],
#   'tags_mti': ['DISH',
#    'granulomatous disease',
#    'opacity',
#    'pleural thickening',
#    'Diaphragm',
#    'Fat Pads',
#    'Pleura'],
#   'images': ['CXR2126_IM-0750-3003.png', 'CXR2126_IM-0750-12012.png']},
#  {'id': 'CXR2490',
#   'comparison': None,
#   'indication': 'History of dyspnea',
#   'findings': None,
#   'impression': 'Heart size is normal. Lungs are clear. Calcified granulomas.',
#   'tags_manual': ['Calcified Granuloma/multiple'],
#   'tags_mti': ['calcified granuloma', 'Granuloma'],
#   'images': ['CXR2490_IM-1017-1001.png', 'CXR2490_IM-1017-2001.png']},
#  {'id': 'CXR1609',
#   'comparison': 'XXXX',
#   'indication': 'The patient is a XXXX-year-old male with history of cirrhosis, SBP, fevers.',
#   'findings': 'Calcified lymph XXXX in both XXXX. XXXX amount of focal atelectasis posterior to the left heart. The trachea is midline. Negative for pneumothorax, pleural effusion or large focal airspace consolidation. The heart size is normal.',
#   'impression': '1. Focal atelectasis to the left lung, posterior to the heart.',
#   'tags_manual': ['Calcinosis/lymph nodes/bilateral',
#    'Pulmonary Atelectasis/left/retrocardiac/focal'],
#   'tags_mti': ['focal atelectasis'],
#   'images': ['CXR1609_IM-0394-1001.png', 'CXR1609_IM-0394-2001.png']},
#  {'id': 'CXR3795',
#   'comparison': 'Thoracic spine XXXX.',
#   'indication': 'Choking sensation.',
#   'findings': '2 images. Moderate thoracic dextroscoliosis, similar to prior imaging. Heart size is normal. No focal airspace consolidation is seen within the lungs. No pleural effusion or pneumothorax.',
#   'impression': 'No acute changes from prior imaging.',
#   'tags_manual': ['Scoliosis/thoracic vertebrae/right/moderate'],
#   'tags_mti': [],
#   'images': ['CXR3795_IM-1909-1001.png', 'CXR3795_IM-1909-2001.png']},
#  {'id': 'CXR1666',
#   'comparison': 'None',
#   'indication': 'Preoperative evaluation, pericardial effusion',
#   'findings': 'The cardiac silhouette is mildly enlarged. There are scattered bilateral XXXX opacities, most notably in the right middle lobe, XXXX XXXX of subsegmental atelectasis. No pleural effusion. No pneumothorax is identified. There are diffuse degenerative changes of the spine.',
#   'impression': '1. Scattered XXXX of subsegmental atelectasis, most notably in the right middle lobe. 2. Mildly enlarged cardiac silhouette; cardiomegaly versus pericardial effusion.',
#   'tags_manual': ['Cardiac Shadow/enlarged/mild',
#    'Opacity/lung/bilateral/scattered',
#    'Opacity/lung/middle lobe/right/scattered',
#    'Pulmonary Atelectasis/middle lobe/right',
#    'Spine/degenerative/diffuse',
#    'Cardiomegaly',
#    'Pericardial Effusion'],
#   'tags_mti': ['atelectases',
#    'degenerative change',
#    'opacity',
#    'pericardial effusion',
#    'Atelectasis',
#    'Cardiomegaly',
#    'Pericardial Effusion'],
#   'images': ['CXR1666_IM-0440-0001-0001.png',
#    'CXR1666_IM-0440-0001-0002.png']},
#  {'id': 'CXR3881',
#   'comparison': 'XXXX.',
#   'indication': 'Cancer of the appendix.',
#   'findings': 'The heart size and pulmonary vascularity appear within normal limits. Right hemidiaphragm remains elevated. No pleural effusion is seen. No pneumothorax is identified. No discrete nodules or adenopathy are noted. Degenerative changes are present in the spine. Right XXXX-a-XXXX has been inserted since the previous study. The tip projects over the lower superior XXXX XXXX.',
#   'impression': '1. No evidence of active disease.',
#   'tags_manual': ['Diaphragm/right/elevated',
#    'Spine/degenerative',
#    'Catheters, Indwelling/right'],
#   'tags_mti': ['degenerative change', 'Diaphragm'],
#   'images': ['CXR3881_IM-1969-3001.png', 'CXR3881_IM-1969-1001.png']},
#  {'id': 'CXR1474',
#   'comparison': 'None',
#   'indication': 'XXXX-year-old female with chest pain',
#   'findings': 'No pneumothorax. Heart size is normal. Granulomas are seen within the right lung. No large pleural effusions. No focal airspace consolidation.',
#   'impression': 'No acute cardiopulmonary abnormalities.',
#   'tags_manual': ['Granuloma/lung/right'],
#   'tags_mti': ['granuloma'],
#   'images': ['CXR1474_IM-0307-1001.png', 'CXR1474_IM-0307-2001.png']},
#  {'id': 'CXR838',
#   'comparison': 'XXXX',
#   'indication': 'XXXX-year-old with pulmonary hypertension',
#   'findings': 'Stable prominence of the cardiac apex, XXXX from ventricular hypertrophy. Mid sternotomy XXXX again noted. No pneumothorax, significant pulmonary edema or large pleural effusions. No focal lung consolidation. Clips in the right upper quadrant consistent with cholecystectomy. Dextroscoliosis of the thoracolumbar spine.',
#   'impression': '1. No acute cardiopulmonary abnormalities.',
#   'tags_manual': ['Heart/apex/prominent',
#    'Thickening/heart ventricles',
#    'Surgical Instruments/right',
#    'Scoliosis/thoracic vertebrae/right',
#    'Scoliosis/lumbar vertebrae/right'],
#   'tags_mti': ['ventricular hypertrophy',
#    'cholecystectomies',
#    'mid sternotomy'],
#   'images': ['CXR838_IM-2362-1001.png', 'CXR838_IM-2362-2001.png']},
#  {'id': 'CXR312',
#   'comparison': 'XXXX, XXXX',
#   'indication': 'XXXX-year-old male with history of lymphoma.',
#   'findings': 'Normal cardiomediastinal silhouette. Left-sided aortic XXXX. Pulmonary vasculatures are within normal limits. Central airways are XXXX. No focal consolidation, pleural effusion or pneumothorax. Bony structure are grossly unremarkable.',
#   'impression': 'No acute pulmonary findings. .',
#   'tags_manual': ['No Indexing'],
#   'tags_mti': [],
#   'images': ['CXR312_IM-1466-1001.png', 'CXR312_IM-1466-2001.png']},
#  {'id': 'CXR1706',
#   'comparison': 'PA and lateral views of the chest on XXXX, XXXX.',
#   'indication': 'Positive PPD',
#   'findings': 'Cardiac silhouette and mediastinal contours are within normal limits. There are low lung volumes. There is no focal opacities. No pneumothorax. No large pleural effusion.',
#   'impression': 'Low lung volumes without acute cardiopulmonary disease.',
#   'tags_manual': ['Lung/hypoinflation'],
#   'tags_mti': [],
#   'images': ['CXR1706_IM-0466-1002.png', 'CXR1706_IM-0466-1001.png']},
#  {'id': 'CXR1668',
#   'comparison': 'None available',
#   'indication': 'XXXX-year-old female with colon sinus symptoms for 3 weeks',
#   'findings': 'No pneumothorax, pleural effusion, or focal airspace disease. There is a discrete 1.4 cm nodule within the anterior segment of the right lower lobe. The additional nodular opacities consistent with chronic granulomatous disease. Heart size normal. Cardiomediastinal silhouette is clear. Bony structures appear intact. Right unilateral nipple ring.',
#   'impression': '1. Negative for acute cardiopulmonary disease. 2. 1.4 cm right lower lobe nodule, XXXX calcified granulomas disease. If patient high XXXX for pulmonary malignancy, consider cross-sectional imaging to verify.',
#   'tags_manual': ['Nodule/lung/lower lobe/right/anterior',
#    'Opacity/round/multiple',
#    'Granulomatous Disease/chronic',
#    'Foreign Bodies/breast/right'],
#   'tags_mti': ['calcified granuloma',
#    'chronic granulomatous disease',
#    'nodule',
#    'opacity',
#    'Granuloma'],
#   'images': ['CXR1668_IM-0441-1002.png', 'CXR1668_IM-0441-1001.png']},
#  {'id': 'CXR3152',
#   'comparison': None,
#   'indication': 'XXXX-year-old male with history of COPD.',
#   'findings': 'The lungs are hyperexpanded. There are stable scattered XXXX bilateral opacities, most notable in the left upper lobe, XXXX scarring. No focal airspace consolidation to suggest pneumonia. No large pleural effusion. No pneumothorax. Heart size is normal. Thoracic aorta is mildly tortuous and demonstrates atherosclerotic vascular calcification. There are degenerative changes of the spine.',
#   'impression': '1. No acute findings. 2. Emphysema. 3. Scattered XXXX of scarring, most notably in the left upper lobe.',
#   'tags_manual': ['Lung/hyperdistention',
#    'Opacity/lung/bilateral/scattered',
#    'Opacity/lung/upper lobe/left/scattered',
#    'Cicatrix/lung/upper lobe/left',
#    'Aorta, Thoracic/tortuous/mild',
#    'Atherosclerosis/aorta, thoracic',
#    'Spine/degenerative',
#    'Emphysema'],
#   'tags_mti': ['degenerative change',
#    'emphysemas',
#    'opacity',
#    'scarring',
#    'vascular calcification',
#    'Emphysema',
#    'Pulmonary Emphysema',
#    'Scarring',
#    'Thoracic Aorta'],
#   'images': ['CXR3152_IM-1484-2001.png', 'CXR3152_IM-1484-1001.png']},
#  ...]

# %%
with open(os.path.join(data_path,'cases.json'),'w') as handle:
    json.dump(cases, handle)

# %% [markdown]
# ### check tags

# %%
tags = []
for case in cases:
    tags += case['tags_mti']
tags_voc = list(set(tags))

# %%
len(tags), len(tags_voc)
# Out:
# (7047, 659)

# %%
tags_voc = [t.lower() for t in tags_voc]

# %%
len(set(tags_voc))
# Out:
# 586

# %% [markdown]
# ### further process tags

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
countvec = CountVectorizer()

# %%
countvec.fit_transform(tags_voc)
# Out:
# <659x517 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1201 stored elements in Compressed Sparse Row format>

# %%
len(countvec.vocabulary_)
# Out:
# 517

# %%
len(countvec.vocabulary_)
# Out:
# 517
