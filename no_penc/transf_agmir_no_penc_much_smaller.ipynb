# %%
# %matplotlib inline

# %%
import os
import torch
from einops import rearrange

# %%
device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:4

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # load data

# %%
from transformer_translation.dataset import ParallelLanguageDataset, load_pickle
from torch.utils.data import DataLoader

# %%
data_path = r"/home/alex/data/nlp/agmir/transf_processed_data"
#data_path = 'transformer_translation/data/processed'

# %%
splits = load_pickle('20200525_splits.pkl')
countvec = load_pickle('20200525_countvec.pkl')

# %% [markdown]
# ### train set

# %%
num_tokens = 2000
max_seq_length = 96
dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['train']
)
loader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(dataset))
# Out:
# 79

# %% [markdown]
# ### val set

# %%
val_dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['val']
)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(val_dataset))
# Out:
# 6

# %% [markdown]
# # train

# %%
from transformer_translation.model import LanguageTransformer, ReportTransformer2

# %%
vocab_size = 10000 + 4#1952#
nhead = 8
d_model = 256
num_encoder_layers = 2
num_decoder_layers = 2
dim_feedforward = 512
pos_dropout = 0.1
trans_dropout = 0.1

model = ReportTransformer2(
    vocab_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward,
    max_seq_length, pos_dropout, trans_dropout
).to(device)

# %%
    from transformer_translation.Optim import ScheduledOptim
    import torch.nn as nn
    from torch.optim import Adam
    
    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_normal_(p)

    n_warmup_steps = 4000
    optim = ScheduledOptim(
        Adam(model.parameters(), betas=(0.9, 0.98), eps=1e-09),
        d_model, n_warmup_steps)

    criterion = nn.CrossEntropyLoss(ignore_index=0)

# %%
from tsf_infer_utils import prep_transf_inputs2, infer2
from torchtext.data.metrics import bleu_score
from tsf_utils import format_list_for_bleu, get_bleu_from_loader2

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 9.230
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 9.196
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 9.097
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 8.976
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 8.796
# Epoch [1 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 8.575
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 8.379
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 8.217
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 7.996
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 7.806
# Epoch [2 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 7.461
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 7.267
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 6.994
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 6.765
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 6.522
# Epoch [3 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 6.154
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 5.884
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 5.658
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 5.357
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 5.157
# Epoch [4 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 5.037
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 4.715
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 4.650
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 4.766
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 4.846
# Epoch [5 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 4.424
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 4.416
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 4.560
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 4.178
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 4.112
# Epoch [6 / 30]:
# 	train BLEU: 2.88%
# 	val BLEU: 1.99%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 3.949
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 3.758
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 3.803
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 3.437
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 3.711
# Epoch [7 / 30]:
# 	train BLEU: 7.73%
# 	val BLEU: 5.58%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 3.584
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 3.452
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 3.169
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 3.109
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 2.954
# Epoch [8 / 30]:
# 	train BLEU: 11.03%
# 	val BLEU: 7.80%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 3.068
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 3.029
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 2.818
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 3.057
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 2.755
# Epoch [9 / 30]:
# 	train BLEU: 11.85%
# 	val BLEU: 8.47%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 2.787
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 2.608
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 2.828
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 2.600
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 2.480
# Epoch [10 / 30]:
# 	train BLEU: 13.62%
# 	val BLEU: 9.28%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 2.665
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 2.311
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 2.536
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 2.312
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 2.546
# Epoch [11 / 30]:
# 	train BLEU: 17.15%
# 	val BLEU: 11.90%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 2.342
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 2.455
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 2.361
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 2.303
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 2.131
# Epoch [12 / 30]:
# 	train BLEU: 18.99%
# 	val BLEU: 13.12%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 2.294
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 2.086
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 2.167
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 2.066
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 2.293
# Epoch [13 / 30]:
# 	train BLEU: 21.03%
# 	val BLEU: 14.36%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 2.273
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 1.881
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 2.105
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 2.120
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 2.037
# Epoch [14 / 30]:
# 	train BLEU: 23.65%
# 	val BLEU: 15.69%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 2.127
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 2.080
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 1.975
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 1.778
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 1.908
# Epoch [15 / 30]:
# 	train BLEU: 25.66%
# 	val BLEU: 17.33%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 1.784
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 1.907
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 2.022
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 1.897
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 1.844
# Epoch [16 / 30]:
# 	train BLEU: 27.13%
# 	val BLEU: 18.23%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 1.989
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 1.342
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 1.616
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 1.821
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 2.137
# Epoch [17 / 30]:
# 	train BLEU: 29.90%
# 	val BLEU: 20.00%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 1.675
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 1.721
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 1.770
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 1.773
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 1.561
# Epoch [18 / 30]:
# 	train BLEU: 31.74%
# 	val BLEU: 21.03%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 1.367
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 1.481
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 1.582
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 1.753
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 1.831
# Epoch [19 / 30]:
# 	train BLEU: 33.90%
# 	val BLEU: 21.88%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 1.544
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 1.766
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 1.495
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 1.418
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 1.484
# Epoch [20 / 30]:
# 	train BLEU: 35.49%
# 	val BLEU: 22.98%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 1.642
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 1.466
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 1.463
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 1.558
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 1.285
# Epoch [21 / 30]:
# 	train BLEU: 36.85%
# 	val BLEU: 23.53%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 1.546
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 1.444
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 1.302
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 1.421
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 1.409
# Epoch [22 / 30]:
# 	train BLEU: 37.94%
# 	val BLEU: 23.99%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 1.269
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 1.623
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 1.262
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 1.141
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 1.558
# Epoch [23 / 30]:
# 	train BLEU: 39.66%
# 	val BLEU: 25.12%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 1.174
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 1.436
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 1.269
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 1.449
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 1.316
# Epoch [24 / 30]:
# 	train BLEU: 41.13%
# 	val BLEU: 25.67%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 1.162
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 1.422
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 1.178
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 1.187
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 1.328
# Epoch [25 / 30]:
# 	train BLEU: 42.44%
# 	val BLEU: 26.23%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 1.170
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 1.255
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 1.191
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 1.061
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 1.459
# Epoch [26 / 30]:
# 	train BLEU: 43.90%
# 	val BLEU: 26.72%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 0.994
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 1.179
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 1.132
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 1.217
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 1.290
# Epoch [27 / 30]:
# 	train BLEU: 45.72%
# 	val BLEU: 27.13%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 1.065
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 1.010
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 1.110
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 1.239
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 1.161
# Epoch [28 / 30]:
# 	train BLEU: 46.78%
# 	val BLEU: 27.39%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 1.186
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 1.056
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.969
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 1.098
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 0.971
# Epoch [29 / 30]:
# 	train BLEU: 47.66%
# 	val BLEU: 26.85%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 0.911
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.997
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 1.035
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 0.953
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 1.098
# Epoch [30 / 30]:
# 	train BLEU: 50.69%
# 	val BLEU: 27.99%
#
#
# CPU times: user 2h 3min 12s, sys: 7min 21s, total: 2h 10min 34s
# Wall time: 10min 45s

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 0.945
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 0.892
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 1.048
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 0.863
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 1.075
# Epoch [1 / 30]:
# 	train BLEU: 51.85%
# 	val BLEU: 27.97%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 0.983
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 1.002
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 0.880
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 0.866
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 0.946
# Epoch [2 / 30]:
# 	train BLEU: 53.16%
# 	val BLEU: 28.39%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 0.842
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 0.875
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 0.969
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 0.834
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 0.938
# Epoch [3 / 30]:
# 	train BLEU: 53.66%
# 	val BLEU: 27.57%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 0.754
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 0.805
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 0.905
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 0.906
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 0.934
# Epoch [4 / 30]:
# 	train BLEU: 56.20%
# 	val BLEU: 28.68%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 0.793
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 0.782
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 0.802
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 0.834
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 0.914
# Epoch [5 / 30]:
# 	train BLEU: 57.67%
# 	val BLEU: 28.96%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 0.810
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 0.761
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 0.839
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 0.735
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 0.786
# Epoch [6 / 30]:
# 	train BLEU: 59.30%
# 	val BLEU: 28.38%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 0.712
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 0.768
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 0.785
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 0.742
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 0.797
# Epoch [7 / 30]:
# 	train BLEU: 59.88%
# 	val BLEU: 28.85%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 0.675
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 0.762
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 0.783
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 0.655
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 0.740
# Epoch [8 / 30]:
# 	train BLEU: 61.53%
# 	val BLEU: 29.02%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 0.605
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 0.662
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 0.712
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 0.760
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 0.790
# Epoch [9 / 30]:
# 	train BLEU: 62.80%
# 	val BLEU: 28.64%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 0.602
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 0.637
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 0.752
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 0.654
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 0.764
# Epoch [10 / 30]:
# 	train BLEU: 63.59%
# 	val BLEU: 28.79%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 0.643
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 0.554
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 0.629
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 0.698
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 0.745
# Epoch [11 / 30]:
# 	train BLEU: 65.23%
# 	val BLEU: 28.88%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 0.579
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 0.597
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 0.690
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 0.597
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 0.718
# Epoch [12 / 30]:
# 	train BLEU: 64.69%
# 	val BLEU: 28.96%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 0.579
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 0.573
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 0.619
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 0.590
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 0.750
# Epoch [13 / 30]:
# 	train BLEU: 66.73%
# 	val BLEU: 28.86%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 0.566
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 0.575
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 0.616
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 0.577
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 0.634
# Epoch [14 / 30]:
# 	train BLEU: 67.55%
# 	val BLEU: 28.99%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 0.525
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 0.563
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 0.565
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 0.624
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 0.657
# Epoch [15 / 30]:
# 	train BLEU: 68.45%
# 	val BLEU: 29.00%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 0.489
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 0.536
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 0.617
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 0.592
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 0.600
# Epoch [16 / 30]:
# 	train BLEU: 68.49%
# 	val BLEU: 28.89%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 0.538
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 0.518
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 0.545
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 0.592
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 0.572
# Epoch [17 / 30]:
# 	train BLEU: 69.11%
# 	val BLEU: 28.81%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 0.505
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 0.545
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 0.538
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 0.536
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 0.603
# Epoch [18 / 30]:
# 	train BLEU: 70.02%
# 	val BLEU: 28.52%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 0.514
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 0.546
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 0.487
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 0.561
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 0.536
# Epoch [19 / 30]:
# 	train BLEU: 68.07%
# 	val BLEU: 27.90%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 0.520
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 0.493
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 0.562
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 0.555
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 0.539
# Epoch [20 / 30]:
# 	train BLEU: 70.19%
# 	val BLEU: 27.96%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 0.468
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 0.477
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 0.529
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 0.502
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 0.579
# Epoch [21 / 30]:
# 	train BLEU: 70.72%
# 	val BLEU: 28.74%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 0.461
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 0.495
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 0.511
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 0.474
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 0.576
# Epoch [22 / 30]:
# 	train BLEU: 70.83%
# 	val BLEU: 28.56%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 0.454
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 0.487
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 0.523
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 0.497
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 0.483
# Epoch [23 / 30]:
# 	train BLEU: 71.27%
# 	val BLEU: 29.08%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 0.496
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 0.448
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 0.479
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 0.482
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 0.501
# Epoch [24 / 30]:
# 	train BLEU: 72.68%
# 	val BLEU: 29.20%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 0.396
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 0.440
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 0.468
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 0.471
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 0.498
# Epoch [25 / 30]:
# 	train BLEU: 72.43%
# 	val BLEU: 28.96%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 0.414
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 0.428
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 0.433
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 0.511
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 0.457
# Epoch [26 / 30]:
# 	train BLEU: 73.12%
# 	val BLEU: 29.28%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 0.412
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 0.437
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 0.429
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 0.448
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 0.455
# Epoch [27 / 30]:
# 	train BLEU: 74.32%
# 	val BLEU: 29.12%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 0.385
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 0.398
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 0.422
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 0.418
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 0.465
# Epoch [28 / 30]:
# 	train BLEU: 73.66%
# 	val BLEU: 28.74%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 0.389
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 0.389
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.387
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 0.438
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 0.445
# Epoch [29 / 30]:
# 	train BLEU: 74.50%
# 	val BLEU: 28.83%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 0.365
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.380
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 0.400
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 0.390
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 0.456
# Epoch [30 / 30]:
# 	train BLEU: 74.74%
# 	val BLEU: 29.45%
#
#
# CPU times: user 2h 2min 1s, sys: 5min 48s, total: 2h 7min 50s
# Wall time: 12min 3s

# %% [markdown]
# # assess perf

# %% [markdown]
# ### run inference

# %%
test_dataset = TagReportDataset(
    os.path.join(data_path, 'tags/set_raw.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['test']
    ,countvec = countvec
)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(test_dataset))
# Out:
# 6

# %%
# %%time
pred_list, tgt_list = infer(model, test_loader)
# Out:
# CPU times: user 19.5 s, sys: 1.32 s, total: 20.8 s
# Wall time: 906 ms

# %% [markdown]
# ### compute BLEU

# %%
# %%time
pred_list_bleu, tgt_list_bleu = format_list_for_bleu(pred_list, tgt_list)
print('{} BLEU: {:.2%}'.format(
                'test', bleu_score(pred_list_bleu, tgt_list_bleu)))
# Out:
# test BLEU: 40.81%
# CPU times: user 1.58 s, sys: 20 ms, total: 1.6 s
# Wall time: 1.6 s

# %% [markdown]
# ### create vocab dicts

# %%
tags_index2word = dict(zip(range(len(dataset.countvec.vocabulary)), dataset.countvec.vocabulary))

# %%
from transformer_translation.dataset import load_report_voc
reports_index2word = load_report_voc(
    os.path.join(data_path, 'reports', 'voc.pkl'))

# %% [markdown]
# ### assess nat lg perf

# %%
from tsf_utils import print_nl_pred_vs_tgt

# %%
import random
k = 10
sel_idx = random.sample(range(len(pred_list)), k=k)

# %%
print_nl_pred_vs_tgt(
                [pred_list[i] for i in sel_idx]
                ,[tgt_list[i] for i in sel_idx]
                ,reports_index2word
            )
# Out:
# TARGET:   normal chest no evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
# PREDICTION:  no chest heart evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
#
#
# TARGET:   no acute cardiopulmonary abnormality . mediastinal contours are normal . heart size is within normal limits . multiple scattered calcified pulmonary nodules xxxx sequela of prior granulomatous disease . otherwise lungs are clear . . there is no pneumothorax or large pleural effusion . no bony abnormality . .
# PREDICTION:   acute cardiopulmonary abnormality . . contours are within . no size is within normal limits . no calcified calcified granulomas nodules are . of prior granulomatous disease . no lungs are clear without no no is no pneumothorax or large pleural effusion . there acute abnormality . .
#
#
# TARGET:   no acute findings . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
# PREDICTION:  no acute cardiopulmonary . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
#
#
# TARGET:   exam quality limited by hypoinflation and rotation . considering technical factors heart size xxxx mildly enlarged aortic calcifications and ectasia tortuosity mediastinal calcifications suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:   quality limited by body and no . heart technical factors xxxx size and within enlarged . ectasia and aortic tortuosity stable contours suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . no crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   no acute cardiopulmonary disease . . the cardiomediastinal silhouette is normal size and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . .
# PREDICTION:  no acute cardiopulmonary abnormality . the the cardiomediastinal silhouette is normal in and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . bony
#
#
# TARGET:   copd . no acute pulmonary disease . there is hyperinflation of the lungs appear to be clear . there is no pleural effusion or the heart is normal . there are atherosclerotic changes of the aorta . the skeletal structures are normal . .
# PREDICTION:   . no acute pulmonary disease . the is a . the lungs . to be clear . there is no pleural effusion or pneumothorax heart and not in arthritic are no changes of the aorta . arthritic skeletal structures are normal . .
#
#
# TARGET:   low lung volumes otherwise clear . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . normal xxxx . xxxx cholecystectomy . .
# PREDICTION:  no lung volumes with no . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . calcified xxxx . . foreign . .
#
#
# TARGET:   minimal xxxx left base atelectasis infiltrate . otherwise stable exam . mild cardiomegaly unchanged . stable superior mediastinal contour with tortuous aorta . normal pulmonary vascularity . unchanged elevated right hemidiaphragm with minimal right base subsegmental atelectasis . minimal xxxx left basal airspace opacity . unchanged blunting of the right lateral costophrenic xxxx scarring versus xxxx effusion . no pneumothorax . no acute osseous findings . .
# PREDICTION:   left right basilar airspace . . the unremarkable appearance . stable cardiomegaly . . the cardiomegaly mediastinal contour . unchanged aorta . no pulmonary vascularity . no right right hemidiaphragm . xxxx right pleural atelectasis atelectasis or no right right pleural airspace disease . no blunting of the right costophrenic costophrenic xxxx . . atelectasis . . no pneumothorax or no acute bony findings . .
#
#
# TARGET:   mild cardiomegaly no acute pulmonary findings mild cardiomegaly stable mediastinal contours . no focal alveolar consolidation no definite pleural effusion seen . mild bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:  cardiomegaly cardiomegaly . acute pulmonary findings heart cardiomegaly . mediastinal contours . stable focal alveolar consolidation no definite pleural effusion seen . no right crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   mild blunted right costophrenic xxxx which could be due to xxxx effusion or scarring . the heart and mediastinum are normal . the lungs are clear . there is mild blunting of the right costophrenic xxxx . there is no infiltrate mass or pneumothorax . the right internal jugular catheter has been removed . .
# PREDICTION:   bibasilar left costophrenic xxxx . may represent secondary to atelectasis effusion or atelectasis . no cardiomediastinal size mediastinum are within . the lungs are clear . there is no xxxx of the costophrenic costophrenic xxxx . there is no pneumothorax or or pneumothorax . . bony costophrenic jugular catheter has been removed . .
