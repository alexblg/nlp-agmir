# %%
# %matplotlib inline

# %%
import os
import torch
from einops import rearrange

# %%
device = torch.device("cuda:5" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:5

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # load data

# %%
from transformer_translation.dataset import ParallelLanguageDataset, load_pickle
from torch.utils.data import DataLoader

# %%
data_path = r"/home/alex/data/nlp/agmir/transf_processed_data"
#data_path = 'transformer_translation/data/processed'

# %%
splits = load_pickle('20200525_splits.pkl')
countvec = load_pickle('20200525_countvec.pkl')

# %% [markdown]
# ### train set

# %%
num_tokens = 2000
max_seq_length = 96
dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['train']
)
loader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(dataset))
# Out:
# 79

# %% [markdown]
# ### val set

# %%
val_dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['val']
)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(val_dataset))
# Out:
# 6

# %% [markdown]
# # train

# %%
from transformer_translation.model import LanguageTransformer, ReportTransformer2

# %%
vocab_size = 10000 + 4#1952#
nhead = 8
d_model = 512
num_encoder_layers = 6
num_decoder_layers = 6
dim_feedforward = 2048
pos_dropout = 0.1
trans_dropout = 0.1

model = ReportTransformer2(
    vocab_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward,
    max_seq_length, pos_dropout, trans_dropout
).to(device)

# %%
    from transformer_translation.Optim import ScheduledOptim
    import torch.nn as nn
    from torch.optim import Adam
    
    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_normal_(p)

    n_warmup_steps = 2000
    optim = ScheduledOptim(
        Adam(model.parameters(), betas=(0.9, 0.98), eps=1e-09),
        d_model, n_warmup_steps)

    criterion = nn.CrossEntropyLoss(ignore_index=0)

# %%
from tsf_infer_utils import prep_transf_inputs2, infer2
from torchtext.data.metrics import bleu_score
from tsf_utils import format_list_for_bleu, get_bleu_from_loader2

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 9.147
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 8.583
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 8.084
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 7.688
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 7.315
# Epoch [1 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 6.703
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 6.397
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 5.932
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 5.456
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 5.217
# Epoch [2 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 4.963
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 4.921
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 4.464
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 4.156
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 4.058
# Epoch [3 / 30]:
# 	train BLEU: 7.86%
# 	val BLEU: 5.63%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 3.677
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 3.931
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 3.363
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 3.037
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 3.016
# Epoch [4 / 30]:
# 	train BLEU: 12.01%
# 	val BLEU: 8.47%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 3.313
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 2.706
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 2.555
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 2.841
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 2.599
# Epoch [5 / 30]:
# 	train BLEU: 17.30%
# 	val BLEU: 12.03%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 2.554
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 2.649
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 2.804
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 2.339
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 2.209
# Epoch [6 / 30]:
# 	train BLEU: 19.21%
# 	val BLEU: 13.45%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 2.467
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 2.173
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 2.325
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 2.059
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 2.465
# Epoch [7 / 30]:
# 	train BLEU: 23.77%
# 	val BLEU: 16.30%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 2.061
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 1.879
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 1.993
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 2.365
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 2.067
# Epoch [8 / 30]:
# 	train BLEU: 26.24%
# 	val BLEU: 17.84%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 1.732
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 1.752
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 2.043
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 2.215
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 2.010
# Epoch [9 / 30]:
# 	train BLEU: 28.44%
# 	val BLEU: 19.54%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 1.959
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 1.794
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 1.968
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 1.742
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 1.665
# Epoch [10 / 30]:
# 	train BLEU: 32.03%
# 	val BLEU: 21.75%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 1.741
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 1.811
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 1.605
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 1.941
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 1.691
# Epoch [11 / 30]:
# 	train BLEU: 33.06%
# 	val BLEU: 22.44%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 1.776
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 1.602
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 1.493
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 1.773
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 1.632
# Epoch [12 / 30]:
# 	train BLEU: 34.23%
# 	val BLEU: 22.94%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 1.627
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 1.426
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 1.470
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 1.513
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 1.735
# Epoch [13 / 30]:
# 	train BLEU: 36.95%
# 	val BLEU: 24.56%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 0.982
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 1.754
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 1.734
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 1.362
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 1.595
# Epoch [14 / 30]:
# 	train BLEU: 37.89%
# 	val BLEU: 24.99%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 1.424
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 1.483
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 1.515
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 1.279
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 1.496
# Epoch [15 / 30]:
# 	train BLEU: 39.25%
# 	val BLEU: 26.10%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 1.169
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 1.387
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 1.592
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 1.475
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 1.221
# Epoch [16 / 30]:
# 	train BLEU: 38.61%
# 	val BLEU: 25.49%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 1.052
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 1.293
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 1.369
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 1.508
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 1.506
# Epoch [17 / 30]:
# 	train BLEU: 41.31%
# 	val BLEU: 26.65%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 1.226
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 1.208
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 1.117
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 1.238
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 1.434
# Epoch [18 / 30]:
# 	train BLEU: 40.66%
# 	val BLEU: 25.81%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 1.252
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 1.353
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 1.156
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 1.222
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 1.366
# Epoch [19 / 30]:
# 	train BLEU: 43.80%
# 	val BLEU: 27.60%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 1.231
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 1.006
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 1.286
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 1.295
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 1.221
# Epoch [20 / 30]:
# 	train BLEU: 43.76%
# 	val BLEU: 26.89%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 0.965
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 1.278
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 1.204
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 1.285
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 1.148
# Epoch [21 / 30]:
# 	train BLEU: 45.46%
# 	val BLEU: 27.36%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 0.986
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 1.090
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 1.222
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 1.130
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 1.379
# Epoch [22 / 30]:
# 	train BLEU: 43.58%
# 	val BLEU: 26.65%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 1.082
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 0.868
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 0.988
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 1.257
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 1.326
# Epoch [23 / 30]:
# 	train BLEU: 45.58%
# 	val BLEU: 26.71%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 1.122
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 1.134
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 1.135
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 1.124
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 1.105
# Epoch [24 / 30]:
# 	train BLEU: 46.44%
# 	val BLEU: 27.12%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 1.050
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 1.050
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 1.013
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 1.123
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 1.142
# Epoch [25 / 30]:
# 	train BLEU: 48.41%
# 	val BLEU: 27.87%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 0.985
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 1.077
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 1.011
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 1.043
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 1.105
# Epoch [26 / 30]:
# 	train BLEU: 47.56%
# 	val BLEU: 26.84%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 0.949
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 1.024
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 0.997
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 1.032
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 1.160
# Epoch [27 / 30]:
# 	train BLEU: 49.62%
# 	val BLEU: 28.27%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 0.962
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 1.001
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 0.964
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 1.009
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 0.997
# Epoch [28 / 30]:
# 	train BLEU: 51.05%
# 	val BLEU: 28.50%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 0.848
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 0.926
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.943
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 0.930
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 0.964
# Epoch [29 / 30]:
# 	train BLEU: 51.20%
# 	val BLEU: 28.22%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 0.934
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.733
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 0.809
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 1.088
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 1.007
# Epoch [30 / 30]:
# 	train BLEU: 54.23%
# 	val BLEU: 28.80%
#
#
# CPU times: user 4h 59min, sys: 10min 41s, total: 5h 9min 41s
# Wall time: 13min 42s

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 0.874
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 0.780
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 0.850
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 0.869
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 0.703
# Epoch [1 / 30]:
# 	train BLEU: 55.53%
# 	val BLEU: 28.64%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 0.750
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 0.718
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 0.868
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 0.824
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 0.828
# Epoch [2 / 30]:
# 	train BLEU: 56.85%
# 	val BLEU: 29.24%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 0.627
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 0.785
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 0.883
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 0.695
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 0.694
# Epoch [3 / 30]:
# 	train BLEU: 56.78%
# 	val BLEU: 28.16%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 0.714
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 0.706
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 0.751
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 0.697
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 0.811
# Epoch [4 / 30]:
# 	train BLEU: 59.74%
# 	val BLEU: 29.14%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 0.637
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 0.607
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 0.721
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 0.696
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 0.718
# Epoch [5 / 30]:
# 	train BLEU: 61.59%
# 	val BLEU: 28.90%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 0.671
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 0.545
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 0.612
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 0.708
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 0.716
# Epoch [6 / 30]:
# 	train BLEU: 62.09%
# 	val BLEU: 28.88%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 0.508
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 0.661
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 0.589
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 0.726
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 0.691
# Epoch [7 / 30]:
# 	train BLEU: 63.96%
# 	val BLEU: 29.51%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 0.511
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 0.549
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 0.533
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 0.639
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 0.694
# Epoch [8 / 30]:
# 	train BLEU: 65.40%
# 	val BLEU: 28.71%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 0.491
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 0.544
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 0.602
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 0.618
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 0.587
# Epoch [9 / 30]:
# 	train BLEU: 64.96%
# 	val BLEU: 29.28%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 0.509
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 0.457
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 0.561
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 0.607
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 0.626
# Epoch [10 / 30]:
# 	train BLEU: 66.94%
# 	val BLEU: 29.50%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 0.490
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 0.477
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 0.550
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 0.566
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 0.545
# Epoch [11 / 30]:
# 	train BLEU: 67.55%
# 	val BLEU: 29.36%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 0.465
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 0.425
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 0.576
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 0.524
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 0.551
# Epoch [12 / 30]:
# 	train BLEU: 68.31%
# 	val BLEU: 29.21%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 0.435
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 0.543
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 0.473
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 0.459
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 0.561
# Epoch [13 / 30]:
# 	train BLEU: 68.68%
# 	val BLEU: 29.90%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 0.497
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 0.424
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 0.468
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 0.448
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 0.493
# Epoch [14 / 30]:
# 	train BLEU: 70.56%
# 	val BLEU: 30.10%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 0.396
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 0.450
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 0.406
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 0.533
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 0.549
# Epoch [15 / 30]:
# 	train BLEU: 69.62%
# 	val BLEU: 29.45%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 0.442
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 0.446
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 0.406
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 0.483
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 0.435
# Epoch [16 / 30]:
# 	train BLEU: 70.96%
# 	val BLEU: 29.67%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 0.394
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 0.405
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 0.434
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 0.548
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 0.418
# Epoch [17 / 30]:
# 	train BLEU: 70.69%
# 	val BLEU: 29.58%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 0.378
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 0.420
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 0.463
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 0.434
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 0.469
# Epoch [18 / 30]:
# 	train BLEU: 71.23%
# 	val BLEU: 29.44%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 0.406
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 0.370
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 0.454
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 0.446
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 0.457
# Epoch [19 / 30]:
# 	train BLEU: 71.38%
# 	val BLEU: 29.30%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 0.376
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 0.421
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 0.406
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 0.427
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 0.442
# Epoch [20 / 30]:
# 	train BLEU: 70.88%
# 	val BLEU: 29.58%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 0.409
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 0.459
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 0.436
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 0.427
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 0.393
# Epoch [21 / 30]:
# 	train BLEU: 72.26%
# 	val BLEU: 29.68%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 0.353
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 0.397
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 0.392
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 0.408
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 0.374
# Epoch [22 / 30]:
# 	train BLEU: 72.08%
# 	val BLEU: 29.30%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 0.342
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 0.393
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 0.398
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 0.411
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 0.446
# Epoch [23 / 30]:
# 	train BLEU: 71.95%
# 	val BLEU: 29.58%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 0.350
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 0.380
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 0.363
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 0.415
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 0.410
# Epoch [24 / 30]:
# 	train BLEU: 72.26%
# 	val BLEU: 29.82%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 0.355
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 0.390
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 0.376
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 0.416
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 0.432
# Epoch [25 / 30]:
# 	train BLEU: 72.93%
# 	val BLEU: 29.83%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 0.354
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 0.343
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 0.374
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 0.383
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 0.423
# Epoch [26 / 30]:
# 	train BLEU: 72.50%
# 	val BLEU: 29.14%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 0.343
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 0.389
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 0.370
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 0.382
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 0.385
# Epoch [27 / 30]:
# 	train BLEU: 72.90%
# 	val BLEU: 29.50%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 0.336
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 0.398
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 0.362
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 0.379
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 0.385
# Epoch [28 / 30]:
# 	train BLEU: 72.85%
# 	val BLEU: 30.00%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 0.335
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 0.371
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.352
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 0.360
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 0.377
# Epoch [29 / 30]:
# 	train BLEU: 72.89%
# 	val BLEU: 29.57%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 0.349
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.340
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 0.373
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 0.376
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 0.352
# Epoch [30 / 30]:
# 	train BLEU: 73.37%
# 	val BLEU: 29.51%
#
#
# CPU times: user 5h 20min 13s, sys: 14min 58s, total: 5h 35min 11s
# Wall time: 19min 5s

# %% [markdown]
# # assess perf

# %% [markdown]
# ### run inference

# %%
test_dataset = TagReportDataset(
    os.path.join(data_path, 'tags/set_raw.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['test']
    ,countvec = countvec
)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(test_dataset))
# Out:
# 6

# %%
# %%time
pred_list, tgt_list = infer(model, test_loader)
# Out:
# CPU times: user 19.5 s, sys: 1.32 s, total: 20.8 s
# Wall time: 906 ms

# %% [markdown]
# ### compute BLEU

# %%
# %%time
pred_list_bleu, tgt_list_bleu = format_list_for_bleu(pred_list, tgt_list)
print('{} BLEU: {:.2%}'.format(
                'test', bleu_score(pred_list_bleu, tgt_list_bleu)))
# Out:
# test BLEU: 40.81%
# CPU times: user 1.58 s, sys: 20 ms, total: 1.6 s
# Wall time: 1.6 s

# %% [markdown]
# ### create vocab dicts

# %%
tags_index2word = dict(zip(range(len(dataset.countvec.vocabulary)), dataset.countvec.vocabulary))

# %%
from transformer_translation.dataset import load_report_voc
reports_index2word = load_report_voc(
    os.path.join(data_path, 'reports', 'voc.pkl'))

# %% [markdown]
# ### assess nat lg perf

# %%
from tsf_utils import print_nl_pred_vs_tgt

# %%
import random
k = 10
sel_idx = random.sample(range(len(pred_list)), k=k)

# %%
print_nl_pred_vs_tgt(
                [pred_list[i] for i in sel_idx]
                ,[tgt_list[i] for i in sel_idx]
                ,reports_index2word
            )
# Out:
# TARGET:   normal chest no evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
# PREDICTION:  no chest heart evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
#
#
# TARGET:   no acute cardiopulmonary abnormality . mediastinal contours are normal . heart size is within normal limits . multiple scattered calcified pulmonary nodules xxxx sequela of prior granulomatous disease . otherwise lungs are clear . . there is no pneumothorax or large pleural effusion . no bony abnormality . .
# PREDICTION:   acute cardiopulmonary abnormality . . contours are within . no size is within normal limits . no calcified calcified granulomas nodules are . of prior granulomatous disease . no lungs are clear without no no is no pneumothorax or large pleural effusion . there acute abnormality . .
#
#
# TARGET:   no acute findings . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
# PREDICTION:  no acute cardiopulmonary . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
#
#
# TARGET:   exam quality limited by hypoinflation and rotation . considering technical factors heart size xxxx mildly enlarged aortic calcifications and ectasia tortuosity mediastinal calcifications suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:   quality limited by body and no . heart technical factors xxxx size and within enlarged . ectasia and aortic tortuosity stable contours suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . no crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   no acute cardiopulmonary disease . . the cardiomediastinal silhouette is normal size and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . .
# PREDICTION:  no acute cardiopulmonary abnormality . the the cardiomediastinal silhouette is normal in and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . bony
#
#
# TARGET:   copd . no acute pulmonary disease . there is hyperinflation of the lungs appear to be clear . there is no pleural effusion or the heart is normal . there are atherosclerotic changes of the aorta . the skeletal structures are normal . .
# PREDICTION:   . no acute pulmonary disease . the is a . the lungs . to be clear . there is no pleural effusion or pneumothorax heart and not in arthritic are no changes of the aorta . arthritic skeletal structures are normal . .
#
#
# TARGET:   low lung volumes otherwise clear . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . normal xxxx . xxxx cholecystectomy . .
# PREDICTION:  no lung volumes with no . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . calcified xxxx . . foreign . .
#
#
# TARGET:   minimal xxxx left base atelectasis infiltrate . otherwise stable exam . mild cardiomegaly unchanged . stable superior mediastinal contour with tortuous aorta . normal pulmonary vascularity . unchanged elevated right hemidiaphragm with minimal right base subsegmental atelectasis . minimal xxxx left basal airspace opacity . unchanged blunting of the right lateral costophrenic xxxx scarring versus xxxx effusion . no pneumothorax . no acute osseous findings . .
# PREDICTION:   left right basilar airspace . . the unremarkable appearance . stable cardiomegaly . . the cardiomegaly mediastinal contour . unchanged aorta . no pulmonary vascularity . no right right hemidiaphragm . xxxx right pleural atelectasis atelectasis or no right right pleural airspace disease . no blunting of the right costophrenic costophrenic xxxx . . atelectasis . . no pneumothorax or no acute bony findings . .
#
#
# TARGET:   mild cardiomegaly no acute pulmonary findings mild cardiomegaly stable mediastinal contours . no focal alveolar consolidation no definite pleural effusion seen . mild bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:  cardiomegaly cardiomegaly . acute pulmonary findings heart cardiomegaly . mediastinal contours . stable focal alveolar consolidation no definite pleural effusion seen . no right crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   mild blunted right costophrenic xxxx which could be due to xxxx effusion or scarring . the heart and mediastinum are normal . the lungs are clear . there is mild blunting of the right costophrenic xxxx . there is no infiltrate mass or pneumothorax . the right internal jugular catheter has been removed . .
# PREDICTION:   bibasilar left costophrenic xxxx . may represent secondary to atelectasis effusion or atelectasis . no cardiomediastinal size mediastinum are within . the lungs are clear . there is no xxxx of the costophrenic costophrenic xxxx . there is no pneumothorax or or pneumothorax . . bony costophrenic jugular catheter has been removed . .
