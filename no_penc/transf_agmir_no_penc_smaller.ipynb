# %%
# %matplotlib inline

# %%
import os
import torch
from einops import rearrange

# %%
device = torch.device("cuda:4" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:4

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # load data

# %%
from transformer_translation.dataset import ParallelLanguageDataset, load_pickle
from torch.utils.data import DataLoader

# %%
data_path = r"/home/alex/data/nlp/agmir/transf_processed_data"
#data_path = 'transformer_translation/data/processed'

# %%
splits = load_pickle('20200525_splits.pkl')
countvec = load_pickle('20200525_countvec.pkl')

# %% [markdown]
# ### train set

# %%
num_tokens = 2000
max_seq_length = 96
dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['train']
)
loader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(dataset))
# Out:
# 79

# %% [markdown]
# ### val set

# %%
val_dataset = ParallelLanguageDataset(
    os.path.join(data_path, 'tags/set.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['val']
)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(val_dataset))
# Out:
# 6

# %% [markdown]
# # train

# %%
from transformer_translation.model import LanguageTransformer, ReportTransformer2

# %%
vocab_size = 10000 + 4#1952#
nhead = 8
d_model = 256
num_encoder_layers = 6
num_decoder_layers = 6
dim_feedforward = 2048
pos_dropout = 0.1
trans_dropout = 0.1

model = ReportTransformer2(
    vocab_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward,
    max_seq_length, pos_dropout, trans_dropout
).to(device)

# %%
    from transformer_translation.Optim import ScheduledOptim
    import torch.nn as nn
    from torch.optim import Adam
    
    for p in model.parameters():
        if p.dim() > 1:
            nn.init.xavier_normal_(p)

    n_warmup_steps = 4000
    optim = ScheduledOptim(
        Adam(model.parameters(), betas=(0.9, 0.98), eps=1e-09),
        d_model, n_warmup_steps)

    criterion = nn.CrossEntropyLoss(ignore_index=0)

# %%
from tsf_infer_utils import prep_transf_inputs2, infer2
from torchtext.data.metrics import bleu_score
from tsf_utils import format_list_for_bleu, get_bleu_from_loader2

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 9.179
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 9.051
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 8.871
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 8.704
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 8.523
# Epoch [1 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 8.331
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 8.224
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 8.116
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 7.837
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 7.674
# Epoch [2 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 7.322
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 7.133
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 6.830
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 6.635
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 6.375
# Epoch [3 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 5.981
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 5.740
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 5.546
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 5.338
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 5.039
# Epoch [4 / 30]:
# 	train BLEU: 0.00%
# 	val BLEU: 0.00%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 4.874
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 4.679
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 4.669
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 4.412
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 4.410
# Epoch [5 / 30]:
# 	train BLEU: 3.53%
# 	val BLEU: 2.28%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 4.190
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 3.960
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 4.178
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 3.795
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 3.691
# Epoch [6 / 30]:
# 	train BLEU: 8.90%
# 	val BLEU: 6.34%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 3.332
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 3.253
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 3.485
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 3.496
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 3.512
# Epoch [7 / 30]:
# 	train BLEU: 11.84%
# 	val BLEU: 8.47%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 3.148
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 3.267
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 2.880
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 2.899
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 2.732
# Epoch [8 / 30]:
# 	train BLEU: 14.78%
# 	val BLEU: 10.15%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 2.851
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 2.728
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 2.465
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 2.829
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 2.975
# Epoch [9 / 30]:
# 	train BLEU: 16.21%
# 	val BLEU: 11.19%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 2.774
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 2.418
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 2.700
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 2.496
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 2.104
# Epoch [10 / 30]:
# 	train BLEU: 18.45%
# 	val BLEU: 12.50%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 2.437
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 2.561
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 2.263
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 2.366
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 2.142
# Epoch [11 / 30]:
# 	train BLEU: 21.43%
# 	val BLEU: 15.08%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 2.140
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 2.394
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 2.331
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 2.457
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 1.969
# Epoch [12 / 30]:
# 	train BLEU: 22.96%
# 	val BLEU: 15.58%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 1.909
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 1.905
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 2.468
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 1.996
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 2.218
# Epoch [13 / 30]:
# 	train BLEU: 25.19%
# 	val BLEU: 17.04%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 1.609
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 2.114
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 2.301
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 1.969
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 2.207
# Epoch [14 / 30]:
# 	train BLEU: 27.10%
# 	val BLEU: 18.75%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 2.292
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 1.701
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 1.843
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 1.925
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 1.917
# Epoch [15 / 30]:
# 	train BLEU: 29.34%
# 	val BLEU: 20.03%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 1.896
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 1.855
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 2.012
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 1.722
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 1.760
# Epoch [16 / 30]:
# 	train BLEU: 31.90%
# 	val BLEU: 21.57%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 1.703
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 1.701
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 1.904
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 1.731
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 1.768
# Epoch [17 / 30]:
# 	train BLEU: 32.73%
# 	val BLEU: 22.26%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 1.521
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 1.921
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 1.788
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 1.804
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 1.716
# Epoch [18 / 30]:
# 	train BLEU: 33.77%
# 	val BLEU: 23.20%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 1.517
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 1.591
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 1.773
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 1.584
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 1.682
# Epoch [19 / 30]:
# 	train BLEU: 35.19%
# 	val BLEU: 23.69%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 1.666
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 1.775
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 1.567
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 1.522
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 1.364
# Epoch [20 / 30]:
# 	train BLEU: 37.20%
# 	val BLEU: 25.14%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 1.352
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 1.420
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 1.555
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 1.658
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 1.449
# Epoch [21 / 30]:
# 	train BLEU: 39.29%
# 	val BLEU: 26.19%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 1.426
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 1.493
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 1.286
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 1.724
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 1.355
# Epoch [22 / 30]:
# 	train BLEU: 39.62%
# 	val BLEU: 26.10%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 1.447
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 1.390
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 1.353
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 1.512
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 1.317
# Epoch [23 / 30]:
# 	train BLEU: 40.84%
# 	val BLEU: 26.87%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 1.257
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 1.346
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 1.525
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 1.462
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 1.278
# Epoch [24 / 30]:
# 	train BLEU: 41.32%
# 	val BLEU: 26.99%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 1.291
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 1.290
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 1.311
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 1.226
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 1.413
# Epoch [25 / 30]:
# 	train BLEU: 43.36%
# 	val BLEU: 28.01%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 1.261
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 1.329
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 1.249
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 1.238
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 1.172
# Epoch [26 / 30]:
# 	train BLEU: 43.92%
# 	val BLEU: 28.09%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 1.012
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 1.367
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 1.328
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 1.179
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 1.243
# Epoch [27 / 30]:
# 	train BLEU: 44.45%
# 	val BLEU: 28.13%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 1.284
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 1.145
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 1.125
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 1.023
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 1.325
# Epoch [28 / 30]:
# 	train BLEU: 45.40%
# 	val BLEU: 28.32%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 1.062
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 0.981
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.959
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 1.208
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 1.283
# Epoch [29 / 30]:
# 	train BLEU: 47.50%
# 	val BLEU: 28.55%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 1.183
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.959
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 1.150
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 1.040
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 1.082
# Epoch [30 / 30]:
# 	train BLEU: 47.58%
# 	val BLEU: 28.45%
#
#
# CPU times: user 4h 50min 14s, sys: 15min 5s, total: 5h 5min 19s
# Wall time: 15min 7s

# %%
    # %%time
    print_every = 15
    num_epochs = 30
    early_stopping_flag = True

    lowest_val = 1e9
    val_losses = []
    total_step = 0
    
    for epoch in range(num_epochs):
        
        model.train()
        total_loss = 0

        for step, (src, src_key_padding_mask, tgt, tgt_key_padding_mask) in enumerate(iter(loader)):
            total_step += 1

            src, src_key_padding_mask, tgt, tgt_key_padding_mask, memory_key_padding_mask, tgt_inp, tgt_out, tgt_mask = prep_transf_inputs2(
                src, src_key_padding_mask, tgt, tgt_key_padding_mask, device)
            
            optim.zero_grad()
            outputs = model(src, tgt_inp, src_key_padding_mask, tgt_key_padding_mask[:, :-1], memory_key_padding_mask, tgt_mask)
            loss = criterion(rearrange(outputs, 'b t v -> (b t) v'), rearrange(tgt_out, 'b o -> (b o)'))

            loss.backward()
            optim.step_and_update_lr()

            total_loss += loss.item()
            if step % print_every == print_every - 1:
                print(f'Epoch [{epoch + 1} / {num_epochs}] \t Step [{step + 1} / {len(loader)}] \t '
                      'Train Loss: {:.3f}'.format(total_loss / print_every))
                total_loss = 0
                
        if early_stopping_flag:
            model.eval()
            print(f'Epoch [{epoch + 1} / {num_epochs}]:')
            print('{} BLEU: {:.2%}'.format(
                '\ttrain', get_bleu_from_loader2(model, loader)))
            print('{} BLEU: {:.2%}'.format(
                '\tval', get_bleu_from_loader2(model, val_loader)))
        print('\n')
# Out:
# Epoch [1 / 30] 	 Step [15 / 79] 	 Train Loss: 0.937
# Epoch [1 / 30] 	 Step [30 / 79] 	 Train Loss: 1.016
# Epoch [1 / 30] 	 Step [45 / 79] 	 Train Loss: 1.018
# Epoch [1 / 30] 	 Step [60 / 79] 	 Train Loss: 1.046
# Epoch [1 / 30] 	 Step [75 / 79] 	 Train Loss: 1.154
# Epoch [1 / 30]:
# 	train BLEU: 49.36%
# 	val BLEU: 29.24%
#
#
# Epoch [2 / 30] 	 Step [15 / 79] 	 Train Loss: 0.905
# Epoch [2 / 30] 	 Step [30 / 79] 	 Train Loss: 0.989
# Epoch [2 / 30] 	 Step [45 / 79] 	 Train Loss: 1.086
# Epoch [2 / 30] 	 Step [60 / 79] 	 Train Loss: 0.709
# Epoch [2 / 30] 	 Step [75 / 79] 	 Train Loss: 1.235
# Epoch [2 / 30]:
# 	train BLEU: 50.64%
# 	val BLEU: 29.07%
#
#
# Epoch [3 / 30] 	 Step [15 / 79] 	 Train Loss: 0.827
# Epoch [3 / 30] 	 Step [30 / 79] 	 Train Loss: 0.912
# Epoch [3 / 30] 	 Step [45 / 79] 	 Train Loss: 1.013
# Epoch [3 / 30] 	 Step [60 / 79] 	 Train Loss: 1.041
# Epoch [3 / 30] 	 Step [75 / 79] 	 Train Loss: 1.021
# Epoch [3 / 30]:
# 	train BLEU: 52.96%
# 	val BLEU: 29.44%
#
#
# Epoch [4 / 30] 	 Step [15 / 79] 	 Train Loss: 0.754
# Epoch [4 / 30] 	 Step [30 / 79] 	 Train Loss: 0.908
# Epoch [4 / 30] 	 Step [45 / 79] 	 Train Loss: 1.078
# Epoch [4 / 30] 	 Step [60 / 79] 	 Train Loss: 1.009
# Epoch [4 / 30] 	 Step [75 / 79] 	 Train Loss: 0.808
# Epoch [4 / 30]:
# 	train BLEU: 52.71%
# 	val BLEU: 29.32%
#
#
# Epoch [5 / 30] 	 Step [15 / 79] 	 Train Loss: 0.809
# Epoch [5 / 30] 	 Step [30 / 79] 	 Train Loss: 0.810
# Epoch [5 / 30] 	 Step [45 / 79] 	 Train Loss: 0.844
# Epoch [5 / 30] 	 Step [60 / 79] 	 Train Loss: 0.870
# Epoch [5 / 30] 	 Step [75 / 79] 	 Train Loss: 0.993
# Epoch [5 / 30]:
# 	train BLEU: 54.88%
# 	val BLEU: 28.98%
#
#
# Epoch [6 / 30] 	 Step [15 / 79] 	 Train Loss: 0.801
# Epoch [6 / 30] 	 Step [30 / 79] 	 Train Loss: 0.870
# Epoch [6 / 30] 	 Step [45 / 79] 	 Train Loss: 0.730
# Epoch [6 / 30] 	 Step [60 / 79] 	 Train Loss: 1.039
# Epoch [6 / 30] 	 Step [75 / 79] 	 Train Loss: 0.712
# Epoch [6 / 30]:
# 	train BLEU: 55.56%
# 	val BLEU: 29.06%
#
#
# Epoch [7 / 30] 	 Step [15 / 79] 	 Train Loss: 0.739
# Epoch [7 / 30] 	 Step [30 / 79] 	 Train Loss: 0.658
# Epoch [7 / 30] 	 Step [45 / 79] 	 Train Loss: 0.834
# Epoch [7 / 30] 	 Step [60 / 79] 	 Train Loss: 0.799
# Epoch [7 / 30] 	 Step [75 / 79] 	 Train Loss: 0.994
# Epoch [7 / 30]:
# 	train BLEU: 58.63%
# 	val BLEU: 29.62%
#
#
# Epoch [8 / 30] 	 Step [15 / 79] 	 Train Loss: 0.641
# Epoch [8 / 30] 	 Step [30 / 79] 	 Train Loss: 0.749
# Epoch [8 / 30] 	 Step [45 / 79] 	 Train Loss: 0.735
# Epoch [8 / 30] 	 Step [60 / 79] 	 Train Loss: 0.811
# Epoch [8 / 30] 	 Step [75 / 79] 	 Train Loss: 0.958
# Epoch [8 / 30]:
# 	train BLEU: 57.77%
# 	val BLEU: 29.06%
#
#
# Epoch [9 / 30] 	 Step [15 / 79] 	 Train Loss: 0.658
# Epoch [9 / 30] 	 Step [30 / 79] 	 Train Loss: 0.722
# Epoch [9 / 30] 	 Step [45 / 79] 	 Train Loss: 0.784
# Epoch [9 / 30] 	 Step [60 / 79] 	 Train Loss: 0.825
# Epoch [9 / 30] 	 Step [75 / 79] 	 Train Loss: 0.625
# Epoch [9 / 30]:
# 	train BLEU: 59.48%
# 	val BLEU: 29.39%
#
#
# Epoch [10 / 30] 	 Step [15 / 79] 	 Train Loss: 0.698
# Epoch [10 / 30] 	 Step [30 / 79] 	 Train Loss: 0.726
# Epoch [10 / 30] 	 Step [45 / 79] 	 Train Loss: 0.748
# Epoch [10 / 30] 	 Step [60 / 79] 	 Train Loss: 0.708
# Epoch [10 / 30] 	 Step [75 / 79] 	 Train Loss: 0.703
# Epoch [10 / 30]:
# 	train BLEU: 61.10%
# 	val BLEU: 29.74%
#
#
# Epoch [11 / 30] 	 Step [15 / 79] 	 Train Loss: 0.637
# Epoch [11 / 30] 	 Step [30 / 79] 	 Train Loss: 0.674
# Epoch [11 / 30] 	 Step [45 / 79] 	 Train Loss: 0.674
# Epoch [11 / 30] 	 Step [60 / 79] 	 Train Loss: 0.775
# Epoch [11 / 30] 	 Step [75 / 79] 	 Train Loss: 0.698
# Epoch [11 / 30]:
# 	train BLEU: 61.46%
# 	val BLEU: 29.26%
#
#
# Epoch [12 / 30] 	 Step [15 / 79] 	 Train Loss: 0.579
# Epoch [12 / 30] 	 Step [30 / 79] 	 Train Loss: 0.672
# Epoch [12 / 30] 	 Step [45 / 79] 	 Train Loss: 0.648
# Epoch [12 / 30] 	 Step [60 / 79] 	 Train Loss: 0.808
# Epoch [12 / 30] 	 Step [75 / 79] 	 Train Loss: 0.701
# Epoch [12 / 30]:
# 	train BLEU: 64.98%
# 	val BLEU: 29.49%
#
#
# Epoch [13 / 30] 	 Step [15 / 79] 	 Train Loss: 0.528
# Epoch [13 / 30] 	 Step [30 / 79] 	 Train Loss: 0.670
# Epoch [13 / 30] 	 Step [45 / 79] 	 Train Loss: 0.635
# Epoch [13 / 30] 	 Step [60 / 79] 	 Train Loss: 0.713
# Epoch [13 / 30] 	 Step [75 / 79] 	 Train Loss: 0.692
# Epoch [13 / 30]:
# 	train BLEU: 64.54%
# 	val BLEU: 29.71%
#
#
# Epoch [14 / 30] 	 Step [15 / 79] 	 Train Loss: 0.559
# Epoch [14 / 30] 	 Step [30 / 79] 	 Train Loss: 0.681
# Epoch [14 / 30] 	 Step [45 / 79] 	 Train Loss: 0.619
# Epoch [14 / 30] 	 Step [60 / 79] 	 Train Loss: 0.617
# Epoch [14 / 30] 	 Step [75 / 79] 	 Train Loss: 0.598
# Epoch [14 / 30]:
# 	train BLEU: 64.81%
# 	val BLEU: 29.17%
#
#
# Epoch [15 / 30] 	 Step [15 / 79] 	 Train Loss: 0.565
# Epoch [15 / 30] 	 Step [30 / 79] 	 Train Loss: 0.655
# Epoch [15 / 30] 	 Step [45 / 79] 	 Train Loss: 0.603
# Epoch [15 / 30] 	 Step [60 / 79] 	 Train Loss: 0.611
# Epoch [15 / 30] 	 Step [75 / 79] 	 Train Loss: 0.687
# Epoch [15 / 30]:
# 	train BLEU: 65.79%
# 	val BLEU: 29.81%
#
#
# Epoch [16 / 30] 	 Step [15 / 79] 	 Train Loss: 0.569
# Epoch [16 / 30] 	 Step [30 / 79] 	 Train Loss: 0.544
# Epoch [16 / 30] 	 Step [45 / 79] 	 Train Loss: 0.591
# Epoch [16 / 30] 	 Step [60 / 79] 	 Train Loss: 0.566
# Epoch [16 / 30] 	 Step [75 / 79] 	 Train Loss: 0.647
# Epoch [16 / 30]:
# 	train BLEU: 64.58%
# 	val BLEU: 28.78%
#
#
# Epoch [17 / 30] 	 Step [15 / 79] 	 Train Loss: 0.496
# Epoch [17 / 30] 	 Step [30 / 79] 	 Train Loss: 0.610
# Epoch [17 / 30] 	 Step [45 / 79] 	 Train Loss: 0.630
# Epoch [17 / 30] 	 Step [60 / 79] 	 Train Loss: 0.611
# Epoch [17 / 30] 	 Step [75 / 79] 	 Train Loss: 0.587
# Epoch [17 / 30]:
# 	train BLEU: 66.87%
# 	val BLEU: 29.55%
#
#
# Epoch [18 / 30] 	 Step [15 / 79] 	 Train Loss: 0.517
# Epoch [18 / 30] 	 Step [30 / 79] 	 Train Loss: 0.599
# Epoch [18 / 30] 	 Step [45 / 79] 	 Train Loss: 0.570
# Epoch [18 / 30] 	 Step [60 / 79] 	 Train Loss: 0.525
# Epoch [18 / 30] 	 Step [75 / 79] 	 Train Loss: 0.612
# Epoch [18 / 30]:
# 	train BLEU: 66.73%
# 	val BLEU: 29.36%
#
#
# Epoch [19 / 30] 	 Step [15 / 79] 	 Train Loss: 0.519
# Epoch [19 / 30] 	 Step [30 / 79] 	 Train Loss: 0.534
# Epoch [19 / 30] 	 Step [45 / 79] 	 Train Loss: 0.599
# Epoch [19 / 30] 	 Step [60 / 79] 	 Train Loss: 0.614
# Epoch [19 / 30] 	 Step [75 / 79] 	 Train Loss: 0.558
# Epoch [19 / 30]:
# 	train BLEU: 69.12%
# 	val BLEU: 29.41%
#
#
# Epoch [20 / 30] 	 Step [15 / 79] 	 Train Loss: 0.414
# Epoch [20 / 30] 	 Step [30 / 79] 	 Train Loss: 0.482
# Epoch [20 / 30] 	 Step [45 / 79] 	 Train Loss: 0.651
# Epoch [20 / 30] 	 Step [60 / 79] 	 Train Loss: 0.592
# Epoch [20 / 30] 	 Step [75 / 79] 	 Train Loss: 0.592
# Epoch [20 / 30]:
# 	train BLEU: 68.94%
# 	val BLEU: 29.62%
#
#
# Epoch [21 / 30] 	 Step [15 / 79] 	 Train Loss: 0.438
# Epoch [21 / 30] 	 Step [30 / 79] 	 Train Loss: 0.542
# Epoch [21 / 30] 	 Step [45 / 79] 	 Train Loss: 0.557
# Epoch [21 / 30] 	 Step [60 / 79] 	 Train Loss: 0.530
# Epoch [21 / 30] 	 Step [75 / 79] 	 Train Loss: 0.638
# Epoch [21 / 30]:
# 	train BLEU: 69.51%
# 	val BLEU: 29.42%
#
#
# Epoch [22 / 30] 	 Step [15 / 79] 	 Train Loss: 0.517
# Epoch [22 / 30] 	 Step [30 / 79] 	 Train Loss: 0.476
# Epoch [22 / 30] 	 Step [45 / 79] 	 Train Loss: 0.535
# Epoch [22 / 30] 	 Step [60 / 79] 	 Train Loss: 0.498
# Epoch [22 / 30] 	 Step [75 / 79] 	 Train Loss: 0.495
# Epoch [22 / 30]:
# 	train BLEU: 69.37%
# 	val BLEU: 29.47%
#
#
# Epoch [23 / 30] 	 Step [15 / 79] 	 Train Loss: 0.529
# Epoch [23 / 30] 	 Step [30 / 79] 	 Train Loss: 0.451
# Epoch [23 / 30] 	 Step [45 / 79] 	 Train Loss: 0.470
# Epoch [23 / 30] 	 Step [60 / 79] 	 Train Loss: 0.512
# Epoch [23 / 30] 	 Step [75 / 79] 	 Train Loss: 0.565
# Epoch [23 / 30]:
# 	train BLEU: 70.02%
# 	val BLEU: 29.62%
#
#
# Epoch [24 / 30] 	 Step [15 / 79] 	 Train Loss: 0.520
# Epoch [24 / 30] 	 Step [30 / 79] 	 Train Loss: 0.454
# Epoch [24 / 30] 	 Step [45 / 79] 	 Train Loss: 0.484
# Epoch [24 / 30] 	 Step [60 / 79] 	 Train Loss: 0.432
# Epoch [24 / 30] 	 Step [75 / 79] 	 Train Loss: 0.487
# Epoch [24 / 30]:
# 	train BLEU: 68.94%
# 	val BLEU: 28.98%
#
#
# Epoch [25 / 30] 	 Step [15 / 79] 	 Train Loss: 0.486
# Epoch [25 / 30] 	 Step [30 / 79] 	 Train Loss: 0.446
# Epoch [25 / 30] 	 Step [45 / 79] 	 Train Loss: 0.474
# Epoch [25 / 30] 	 Step [60 / 79] 	 Train Loss: 0.528
# Epoch [25 / 30] 	 Step [75 / 79] 	 Train Loss: 0.505
# Epoch [25 / 30]:
# 	train BLEU: 71.87%
# 	val BLEU: 29.48%
#
#
# Epoch [26 / 30] 	 Step [15 / 79] 	 Train Loss: 0.423
# Epoch [26 / 30] 	 Step [30 / 79] 	 Train Loss: 0.418
# Epoch [26 / 30] 	 Step [45 / 79] 	 Train Loss: 0.460
# Epoch [26 / 30] 	 Step [60 / 79] 	 Train Loss: 0.471
# Epoch [26 / 30] 	 Step [75 / 79] 	 Train Loss: 0.422
# Epoch [26 / 30]:
# 	train BLEU: 71.27%
# 	val BLEU: 29.58%
#
#
# Epoch [27 / 30] 	 Step [15 / 79] 	 Train Loss: 0.379
# Epoch [27 / 30] 	 Step [30 / 79] 	 Train Loss: 0.468
# Epoch [27 / 30] 	 Step [45 / 79] 	 Train Loss: 0.441
# Epoch [27 / 30] 	 Step [60 / 79] 	 Train Loss: 0.462
# Epoch [27 / 30] 	 Step [75 / 79] 	 Train Loss: 0.434
# Epoch [27 / 30]:
# 	train BLEU: 72.39%
# 	val BLEU: 29.50%
#
#
# Epoch [28 / 30] 	 Step [15 / 79] 	 Train Loss: 0.395
# Epoch [28 / 30] 	 Step [30 / 79] 	 Train Loss: 0.409
# Epoch [28 / 30] 	 Step [45 / 79] 	 Train Loss: 0.408
# Epoch [28 / 30] 	 Step [60 / 79] 	 Train Loss: 0.425
# Epoch [28 / 30] 	 Step [75 / 79] 	 Train Loss: 0.478
# Epoch [28 / 30]:
# 	train BLEU: 72.35%
# 	val BLEU: 28.89%
#
#
# Epoch [29 / 30] 	 Step [15 / 79] 	 Train Loss: 0.428
# Epoch [29 / 30] 	 Step [30 / 79] 	 Train Loss: 0.401
# Epoch [29 / 30] 	 Step [45 / 79] 	 Train Loss: 0.425
# Epoch [29 / 30] 	 Step [60 / 79] 	 Train Loss: 0.391
# Epoch [29 / 30] 	 Step [75 / 79] 	 Train Loss: 0.397
# Epoch [29 / 30]:
# 	train BLEU: 73.02%
# 	val BLEU: 29.33%
#
#
# Epoch [30 / 30] 	 Step [15 / 79] 	 Train Loss: 0.364
# Epoch [30 / 30] 	 Step [30 / 79] 	 Train Loss: 0.364
# Epoch [30 / 30] 	 Step [45 / 79] 	 Train Loss: 0.400
# Epoch [30 / 30] 	 Step [60 / 79] 	 Train Loss: 0.442
# Epoch [30 / 30] 	 Step [75 / 79] 	 Train Loss: 0.435
# Epoch [30 / 30]:
# 	train BLEU: 73.49%
# 	val BLEU: 29.39%
#
#
# CPU times: user 4h 43min 10s, sys: 12min 8s, total: 4h 55min 19s
# Wall time: 15min 45s

# %% [markdown]
# # assess perf

# %% [markdown]
# ### run inference

# %%
test_dataset = TagReportDataset(
    os.path.join(data_path, 'tags/set_raw.pkl')
    ,os.path.join(data_path, 'reports/set.pkl')
    ,num_tokens
    ,max_seq_length
    ,idxs=splits['test']
    ,countvec = countvec
)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=True, num_workers=4, pin_memory=True)
print(len(test_dataset))
# Out:
# 6

# %%
# %%time
pred_list, tgt_list = infer(model, test_loader)
# Out:
# CPU times: user 19.5 s, sys: 1.32 s, total: 20.8 s
# Wall time: 906 ms

# %% [markdown]
# ### compute BLEU

# %%
# %%time
pred_list_bleu, tgt_list_bleu = format_list_for_bleu(pred_list, tgt_list)
print('{} BLEU: {:.2%}'.format(
                'test', bleu_score(pred_list_bleu, tgt_list_bleu)))
# Out:
# test BLEU: 40.81%
# CPU times: user 1.58 s, sys: 20 ms, total: 1.6 s
# Wall time: 1.6 s

# %% [markdown]
# ### create vocab dicts

# %%
tags_index2word = dict(zip(range(len(dataset.countvec.vocabulary)), dataset.countvec.vocabulary))

# %%
from transformer_translation.dataset import load_report_voc
reports_index2word = load_report_voc(
    os.path.join(data_path, 'reports', 'voc.pkl'))

# %% [markdown]
# ### assess nat lg perf

# %%
from tsf_utils import print_nl_pred_vs_tgt

# %%
import random
k = 10
sel_idx = random.sample(range(len(pred_list)), k=k)

# %%
print_nl_pred_vs_tgt(
                [pred_list[i] for i in sel_idx]
                ,[tgt_list[i] for i in sel_idx]
                ,reports_index2word
            )
# Out:
# TARGET:   normal chest no evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
# PREDICTION:  no chest heart evidence of tuberculosis heart size normal . lungs are clear . xxxx are normal . no pneumonia effusions edema pneumothorax adenopathy nodules or masses . .
#
#
# TARGET:   no acute cardiopulmonary abnormality . mediastinal contours are normal . heart size is within normal limits . multiple scattered calcified pulmonary nodules xxxx sequela of prior granulomatous disease . otherwise lungs are clear . . there is no pneumothorax or large pleural effusion . no bony abnormality . .
# PREDICTION:   acute cardiopulmonary abnormality . . contours are within . no size is within normal limits . no calcified calcified granulomas nodules are . of prior granulomatous disease . no lungs are clear without no no is no pneumothorax or large pleural effusion . there acute abnormality . .
#
#
# TARGET:   no acute findings . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
# PREDICTION:  no acute cardiopulmonary . cardiac and mediastinal contours are within normal limits . the lungs are clear . bony structures are intact . .
#
#
# TARGET:   exam quality limited by hypoinflation and rotation . considering technical factors heart size xxxx mildly enlarged aortic calcifications and ectasia tortuosity mediastinal calcifications suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:   quality limited by body and no . heart technical factors xxxx size and within enlarged . ectasia and aortic tortuosity stable contours suggest a previous granulomatous process . no focal alveolar consolidation no definite pleural effusion seen . no crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   no acute cardiopulmonary disease . . the cardiomediastinal silhouette is normal size and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . .
# PREDICTION:  no acute cardiopulmonary abnormality . the the cardiomediastinal silhouette is normal in and configuration . pulmonary vasculature within normal limits . the lungs are well aerated . there is no pneumothorax pleural effusion or focal consolidation . bony
#
#
# TARGET:   copd . no acute pulmonary disease . there is hyperinflation of the lungs appear to be clear . there is no pleural effusion or the heart is normal . there are atherosclerotic changes of the aorta . the skeletal structures are normal . .
# PREDICTION:   . no acute pulmonary disease . the is a . the lungs . to be clear . there is no pleural effusion or pneumothorax heart and not in arthritic are no changes of the aorta . arthritic skeletal structures are normal . .
#
#
# TARGET:   low lung volumes otherwise clear . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . normal xxxx . xxxx cholecystectomy . .
# PREDICTION:  no lung volumes with no . the cardiomediastinal silhouette is normal in size and contour . no focal consolidation pneumothorax or large pleural effusion . calcified xxxx . . foreign . .
#
#
# TARGET:   minimal xxxx left base atelectasis infiltrate . otherwise stable exam . mild cardiomegaly unchanged . stable superior mediastinal contour with tortuous aorta . normal pulmonary vascularity . unchanged elevated right hemidiaphragm with minimal right base subsegmental atelectasis . minimal xxxx left basal airspace opacity . unchanged blunting of the right lateral costophrenic xxxx scarring versus xxxx effusion . no pneumothorax . no acute osseous findings . .
# PREDICTION:   left right basilar airspace . . the unremarkable appearance . stable cardiomegaly . . the cardiomegaly mediastinal contour . unchanged aorta . no pulmonary vascularity . no right right hemidiaphragm . xxxx right pleural atelectasis atelectasis or no right right pleural airspace disease . no blunting of the right costophrenic costophrenic xxxx . . atelectasis . . no pneumothorax or no acute bony findings . .
#
#
# TARGET:   mild cardiomegaly no acute pulmonary findings mild cardiomegaly stable mediastinal contours . no focal alveolar consolidation no definite pleural effusion seen . mild bronchovascular crowding without typical findings of pulmonary edema . .
# PREDICTION:  cardiomegaly cardiomegaly . acute pulmonary findings heart cardiomegaly . mediastinal contours . stable focal alveolar consolidation no definite pleural effusion seen . no right crowding without typical findings of pulmonary edema . .
#
#
# TARGET:   mild blunted right costophrenic xxxx which could be due to xxxx effusion or scarring . the heart and mediastinum are normal . the lungs are clear . there is mild blunting of the right costophrenic xxxx . there is no infiltrate mass or pneumothorax . the right internal jugular catheter has been removed . .
# PREDICTION:   bibasilar left costophrenic xxxx . may represent secondary to atelectasis effusion or atelectasis . no cardiomediastinal size mediastinum are within . the lungs are clear . there is no xxxx of the costophrenic costophrenic xxxx . there is no pneumothorax or or pneumothorax . . bony costophrenic jugular catheter has been removed . .
